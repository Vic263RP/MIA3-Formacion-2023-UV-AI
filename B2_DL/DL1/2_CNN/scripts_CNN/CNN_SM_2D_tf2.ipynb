# %%
#from __future__ import absolute_import, division, print_function, unicode_literals
# Installa TensorFlow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2024-05-28 17:09:51.341515: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.11.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D
import numpy as np

# %% [markdown]
# Para leer datos lo mejor es usar la toolbox pandas
#
# Los datos se han sacado de:
# https://www.kaggle.com/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/version/3

# %%
import pandas as pd

# Leer los datos 
# En local: tenemos que tener el fichero en la misma carpeta que el notebook (o cambiar la ruta)
# En Colab: abre la carpeta (usando el boton de la izquierda) y arrastralos dentro desde tu ordenador.

dd_googl = pd.read_csv("datos/googl.us.txt", delimiter=",")
dd_aa = pd.read_csv("datos/aa.us.txt", delimiter=",")
dd_iae = pd.read_csv("datos/iae.us.txt", delimiter=",")

# %%
# Estos son los datos de google
dd_googl
# Out:
#             Date      Open     High       Low     Close    Volume  OpenInt
# 0     2004-08-19    50.000    52.03    47.980    50.170  44703800        0
# 1     2004-08-20    50.505    54.54    50.250    54.155  22857200        0
# 2     2004-08-23    55.375    56.74    54.525    54.700  18274400        0
# 3     2004-08-24    55.620    55.80    51.785    52.435  15262600        0
# 4     2004-08-25    52.480    54.00    51.940    53.000   9197800        0
# ...          ...       ...      ...       ...       ...       ...      ...
# 3328  2017-11-06  1049.100  1052.59  1042.000  1042.680    913954        0
# 3329  2017-11-07  1049.650  1053.41  1043.000  1052.390   1303832        0
# 3330  2017-11-08  1050.050  1062.69  1047.050  1058.290   1214469        0
# 3331  2017-11-09  1048.000  1050.88  1035.850  1047.720   1793994        0
# 3332  2017-11-10  1043.870  1046.63  1041.220  1044.150    970498        0
#
# [3333 rows x 7 columns]

# %%
# Nos quedamos con los datos de apertura
googl_op = dd_googl['Open'].values
aa_op = dd_aa['Open'].values
iae_op = dd_iae['Open'].values

# %%
# Como no coinciden en el tiempo los 3 valores me cojo solo los que coinciden
# Primero me los ordeno teniendo en cuenta la fecha
aa = dd_googl['Date'].values
googl_indice = np.zeros(aa.shape)
for n in range(0, aa.shape[0]):
    cc = aa[n]
    qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
    qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
    qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

    googl_indice[n] = (qq1-2000)*365 + qq2*30 + qq3

# %%
aa = dd_aa['Date'].values
aa_indice = np.zeros(aa.shape)
for n in range(0, aa.shape[0]):
    cc = aa[n]
    qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
    qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
    qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

    aa_indice[n] = (qq1-2000)*365 + qq2*30 + qq3

# %%
aa = dd_iae['Date'].values
iae_indice = np.zeros(aa.shape)
for n in range(0, aa.shape[0]):
    cc = aa[n]
    qq1 = np.asarray(cc[0:4], dtype=np.float64, order='C')
    qq2 = np.asarray(cc[5:7], dtype=np.float64, order='C')
    qq3 = np.asarray(cc[8:10], dtype=np.float64, order='C')

    iae_indice[n] = (qq1-2000)*365 + qq2*30 + qq3

# %%
print(googl_indice.shape)
print(googl_op.shape)
# Out:
# (3333,)
# (3333,)

# %%
# Los ploteo y veo que hay un tramo en el coinciden las fechas
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(googl_indice,googl_op)
plt.plot(aa_indice,aa_op)
plt.plot(iae_indice,iae_op)

# %%
# Me quedo solo las fechas que coinciden
indices = set(googl_indice) & set(aa_indice) & set(iae_indice) 

ii = np.in1d(googl_indice,list(indices))
data_googl = googl_op[ii]
ii = np.in1d(aa_indice,list(indices))
data_aa = aa_op[ii]
ii = np.in1d(iae_indice,list(indices))
data_iae = iae_op[ii]

# %%
# Los ploteo y ahora síí coinciden en todo el tramo
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(data_googl)
plt.plot(data_aa)
plt.plot(data_iae)

# %%
# Los coloco todos juntos en un dataset
DAT = np.zeros((data_googl.shape[0],3))
DAT[:,0] = data_googl
DAT[:,1] = data_aa
DAT[:,2] = data_iae

# %%
# Los ploteo
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(DAT[:,0])
plt.plot(DAT[:,1])
plt.plot(DAT[:,2])

# %%
# Dimensiones del dataset
DAT.shape
# Out:
# (2678, 3)

# %%
# Reordeno el dataset para hacer bloques de LAG dias
LAG = 15
DAT_TS = np.zeros((DAT.shape[0]-LAG,LAG,DAT.shape[1]))

for ii in range(0,DAT.shape[0]-LAG):
    DAT_TS[ii,:,:] = DAT[ii:ii+LAG,:]

# %%
# Tengo (#muestras,#longitud,#variables)
DAT_TS.shape
# Out:
# (2663, 15, 3)

# %%
# Cojo 14 dias para entrada y el dia 15 de la variable "Y_target" como variable a predecir
# Separo en train y test

Ntr = np.floor(DAT_TS.shape[0]/2)
Y_target = 0

XX_tr = DAT_TS[range(0,int(Ntr)),0:LAG-1,:]
XX_ts = DAT_TS[range(int(Ntr)+1,2*int(Ntr)),0:LAG-1,:]

YY_tr = DAT_TS[range(0,int(Ntr)),LAG-1,Y_target]
YY_ts = DAT_TS[range(int(Ntr)+1,2*int(Ntr)),LAG-1,Y_target]

LAG-1
# Out:
# 14

# %%
# Los datos de entrada
XX_tr.shape
# Out:
# (1331, 14, 3)

# %%
# Los datos a predecir
YY_tr.shape
# Out:
# (1331,)

# %%
# Modifico las dimensiones para poder usar convoluciones 2D
# Para eso incluyo una dimension de canales al final

XX_tr = XX_tr.reshape(XX_tr.shape[0],XX_tr.shape[1],XX_tr.shape[2],1)
XX_ts = XX_ts.reshape(XX_ts.shape[0],XX_ts.shape[1],XX_ts.shape[2],1)

# %%
XX_tr.shape
# Out:
# (1331, 14, 3, 1)

# %% [markdown]
# KERAS MODEL

# %%
# Definimos un modelo con una capa convolucional 2D y 1 capa densa
model = Sequential()
model.add(Conv2D(10, 3, input_shape=XX_tr.shape[1:], padding='same'))
model.add(Flatten())
model.add(Dense(1))

# mostramos el modelo
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 14, 3, 10)         100
#
#  flatten (Flatten)           (None, 420)               0
#
#  dense (Dense)               (None, 1)                 421
#
# =================================================================
# Total params: 521
# Trainable params: 521
# Non-trainable params: 0
# _________________________________________________________________
# 2024-05-28 17:10:59.956633: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-28 17:10:59.959087: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Otra posibilidad 2 convolucionales 2D y una densa
model = Sequential()
model.add(Conv2D(10, 3, input_shape=XX_tr.shape[1:], padding='same'))
model.add(Conv2D(10, 3, padding='same'))
model.add(Flatten())
model.add(Dense(1))

# mostramos el modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 14, 3, 10)         100
#
#  conv2d_2 (Conv2D)           (None, 14, 3, 10)         910
#
#  flatten_1 (Flatten)         (None, 420)               0
#
#  dense_1 (Dense)             (None, 1)                 421
#
# =================================================================
# Total params: 1,431
# Trainable params: 1,431
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Otra posibilidad 2 convolucionales 2D y 2 densas
model = Sequential()
model.add(Conv2D(10, 3, input_shape=XX_tr.shape[1:], padding='same'))
model.add(Conv2D(10, 3, padding='valid'))
model.add(Flatten())
model.add(Dense(10))
model.add(Dense(1))

# mostramos el modelo
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 14, 3, 10)         100
#
#  conv2d_4 (Conv2D)           (None, 12, 1, 10)         910
#
#  flatten_2 (Flatten)         (None, 120)               0
#
#  dense_2 (Dense)             (None, 10)                1210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2,231
# Trainable params: 2,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilamos el modelo
model.compile(optimizer='adam',loss='mae')

# %%
# Entrenamos el modelo. Para guardarnos la evolucióón usando callbacks

# from keras.callbacks import History 
# history = History()

# model.fit(XX_tr, YY_tr, batch_size=32, epochs=100, verbose=1, callbacks=[history])

# %%
# Entrenamos el modelo, nos guardamos la evolución en 'history' 
# Esto es equivalente a usar callbacks para history
history = model.fit(XX_tr, YY_tr, batch_size=32, epochs=300, verbose=1)
# Out:
# Epoch 1/300
# 42/42 [==============================] - 3s 57ms/step - loss: 46.2780
# Epoch 2/300
# 42/42 [==============================] - 2s 46ms/step - loss: 10.4747
# Epoch 3/300
# 42/42 [==============================] - 2s 51ms/step - loss: 11.0979
# Epoch 4/300
# 42/42 [==============================] - 3s 68ms/step - loss: 9.6566
# Epoch 5/300
# 42/42 [==============================] - 4s 85ms/step - loss: 10.1587
# Epoch 6/300
# 42/42 [==============================] - 3s 67ms/step - loss: 7.9737
# Epoch 7/300
# 42/42 [==============================] - 2s 52ms/step - loss: 7.4793
# Epoch 8/300
# 42/42 [==============================] - 2s 48ms/step - loss: 6.6024
# Epoch 9/300
# 42/42 [==============================] - 2s 48ms/step - loss: 7.8217
# Epoch 10/300
# 42/42 [==============================] - 3s 62ms/step - loss: 6.6015
# Epoch 11/300
# 42/42 [==============================] - 3s 69ms/step - loss: 6.5481
# Epoch 12/300
# 42/42 [==============================] - 2s 52ms/step - loss: 6.2203
# Epoch 13/300
# 42/42 [==============================] - 2s 41ms/step - loss: 5.8775
# Epoch 14/300
# 42/42 [==============================] - 2s 53ms/step - loss: 5.3016
# Epoch 15/300
# 42/42 [==============================] - 4s 86ms/step - loss: 5.5993
# Epoch 16/300
# 42/42 [==============================] - 4s 84ms/step - loss: 6.4697
# Epoch 17/300
# 42/42 [==============================] - 4s 92ms/step - loss: 5.1981
# Epoch 18/300
# 42/42 [==============================] - 4s 88ms/step - loss: 5.8709
# Epoch 19/300
# 42/42 [==============================] - 4s 87ms/step - loss: 5.3602
# Epoch 20/300
# 42/42 [==============================] - 2s 45ms/step - loss: 5.6512
# Epoch 21/300
# 42/42 [==============================] - 2s 49ms/step - loss: 5.6694
# Epoch 22/300
# 42/42 [==============================] - 2s 50ms/step - loss: 5.1555
# Epoch 23/300
# 42/42 [==============================] - 2s 46ms/step - loss: 5.1899
# Epoch 24/300
# 42/42 [==============================] - 2s 47ms/step - loss: 5.0532
# Epoch 25/300
# 42/42 [==============================] - 2s 53ms/step - loss: 4.6366
# Epoch 26/300
# 42/42 [==============================] - 3s 59ms/step - loss: 4.5268
# Epoch 27/300
# 42/42 [==============================] - 2s 46ms/step - loss: 4.6124
# Epoch 28/300
# 42/42 [==============================] - 3s 65ms/step - loss: 4.8451
# Epoch 29/300
# 42/42 [==============================] - 2s 44ms/step - loss: 4.8160
# Epoch 30/300
# 42/42 [==============================] - 2s 46ms/step - loss: 4.7539
# Epoch 31/300
# 42/42 [==============================] - 1s 27ms/step - loss: 4.7465
# Epoch 32/300
# 42/42 [==============================] - 2s 50ms/step - loss: 4.4657
# Epoch 33/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.8939
# Epoch 34/300
# 42/42 [==============================] - 2s 56ms/step - loss: 4.9519
# Epoch 35/300
# 42/42 [==============================] - 2s 45ms/step - loss: 4.6509
# Epoch 36/300
# 42/42 [==============================] - 1s 32ms/step - loss: 4.3398
# Epoch 37/300
# 42/42 [==============================] - 1s 28ms/step - loss: 4.3990
# Epoch 38/300
# 42/42 [==============================] - 3s 73ms/step - loss: 4.7051
# Epoch 39/300
# 42/42 [==============================] - 2s 58ms/step - loss: 5.0445
# Epoch 40/300
# 42/42 [==============================] - 2s 37ms/step - loss: 4.7204
# Epoch 41/300
# 42/42 [==============================] - 1s 23ms/step - loss: 4.8771
# Epoch 42/300
# 42/42 [==============================] - 2s 46ms/step - loss: 4.1073
# Epoch 43/300
# 42/42 [==============================] - 2s 50ms/step - loss: 4.1432
# Epoch 44/300
# 42/42 [==============================] - 2s 46ms/step - loss: 4.0840
# Epoch 45/300
# 42/42 [==============================] - 2s 50ms/step - loss: 5.0599
# Epoch 46/300
# 42/42 [==============================] - 2s 41ms/step - loss: 4.4633
# Epoch 47/300
# 42/42 [==============================] - 3s 71ms/step - loss: 4.6702
# Epoch 48/300
# 42/42 [==============================] - 3s 72ms/step - loss: 4.2471
# Epoch 49/300
# 42/42 [==============================] - 1s 33ms/step - loss: 4.4013
# Epoch 50/300
# 42/42 [==============================] - 3s 68ms/step - loss: 4.9245
# Epoch 51/300
# 42/42 [==============================] - 3s 81ms/step - loss: 4.4130
# Epoch 52/300
# 42/42 [==============================] - 3s 65ms/step - loss: 4.5933
# Epoch 53/300
# 42/42 [==============================] - 3s 73ms/step - loss: 4.3896
# Epoch 54/300
# 42/42 [==============================] - 3s 73ms/step - loss: 4.0533
# Epoch 55/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.4228
# Epoch 56/300
# 42/42 [==============================] - 1s 27ms/step - loss: 3.8359
# Epoch 57/300
# 42/42 [==============================] - 2s 52ms/step - loss: 4.1354
# Epoch 58/300
# 42/42 [==============================] - 3s 62ms/step - loss: 3.9057
# Epoch 59/300
# 42/42 [==============================] - 3s 70ms/step - loss: 4.2499
# Epoch 60/300
# 42/42 [==============================] - 3s 74ms/step - loss: 4.0368
# Epoch 61/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.0713
# Epoch 62/300
# 42/42 [==============================] - 2s 61ms/step - loss: 5.4252
# Epoch 63/300
# 42/42 [==============================] - 3s 65ms/step - loss: 3.8502
# Epoch 64/300
# 42/42 [==============================] - 3s 75ms/step - loss: 3.8618
# Epoch 65/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.7184
# Epoch 66/300
# 42/42 [==============================] - 1s 23ms/step - loss: 4.4979
# Epoch 67/300
# 42/42 [==============================] - 2s 37ms/step - loss: 4.7172
# Epoch 68/300
# 42/42 [==============================] - 1s 26ms/step - loss: 3.8987
# Epoch 69/300
# 42/42 [==============================] - 2s 41ms/step - loss: 4.1477
# Epoch 70/300
# 42/42 [==============================] - 1s 19ms/step - loss: 4.3123
# Epoch 71/300
# 42/42 [==============================] - 2s 39ms/step - loss: 4.3169
# Epoch 72/300
# 42/42 [==============================] - 2s 38ms/step - loss: 4.2017
# Epoch 73/300
# 42/42 [==============================] - 1s 33ms/step - loss: 4.3214
# Epoch 74/300
# 42/42 [==============================] - 2s 40ms/step - loss: 3.8140
# Epoch 75/300
# 42/42 [==============================] - 2s 44ms/step - loss: 4.2329
# Epoch 76/300
# 42/42 [==============================] - 2s 40ms/step - loss: 4.1486
# Epoch 77/300
# 42/42 [==============================] - 1s 32ms/step - loss: 3.9632
# Epoch 78/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.5649
# Epoch 79/300
# 42/42 [==============================] - 1s 27ms/step - loss: 3.8982
# Epoch 80/300
# 42/42 [==============================] - 2s 50ms/step - loss: 4.3227
# Epoch 81/300
# 42/42 [==============================] - 1s 17ms/step - loss: 4.4380
# Epoch 82/300
# 42/42 [==============================] - 2s 58ms/step - loss: 4.8369
# Epoch 83/300
# 42/42 [==============================] - 3s 61ms/step - loss: 4.0743
# Epoch 84/300
# 42/42 [==============================] - 3s 60ms/step - loss: 4.6169
# Epoch 85/300
# 42/42 [==============================] - 3s 62ms/step - loss: 3.7763
# Epoch 86/300
# 42/42 [==============================] - 1s 33ms/step - loss: 3.8425
# Epoch 87/300
# 42/42 [==============================] - 2s 47ms/step - loss: 3.9498
# Epoch 88/300
# 42/42 [==============================] - 1s 18ms/step - loss: 4.0040
# Epoch 89/300
# 42/42 [==============================] - 2s 54ms/step - loss: 5.2229
# Epoch 90/300
# 42/42 [==============================] - 2s 37ms/step - loss: 4.4895
# Epoch 91/300
# 42/42 [==============================] - 1s 15ms/step - loss: 4.0992
# Epoch 92/300
# 42/42 [==============================] - 1s 19ms/step - loss: 3.8522
# Epoch 93/300
# 42/42 [==============================] - 2s 53ms/step - loss: 4.3482
# Epoch 94/300
# 42/42 [==============================] - 2s 52ms/step - loss: 3.9417
# Epoch 95/300
# 42/42 [==============================] - 2s 40ms/step - loss: 4.0971
# Epoch 96/300
# 42/42 [==============================] - 2s 58ms/step - loss: 4.1030
# Epoch 97/300
# 42/42 [==============================] - 2s 45ms/step - loss: 4.1210
# Epoch 98/300
# 42/42 [==============================] - 2s 48ms/step - loss: 4.4796
# Epoch 99/300
# 42/42 [==============================] - 1s 29ms/step - loss: 4.0599
# Epoch 100/300
# 42/42 [==============================] - 1s 22ms/step - loss: 3.8243
# Epoch 101/300
# 42/42 [==============================] - 2s 47ms/step - loss: 3.9622
# Epoch 102/300
# 42/42 [==============================] - 2s 40ms/step - loss: 4.0519
# Epoch 103/300
# 42/42 [==============================] - 2s 51ms/step - loss: 4.3984
# Epoch 104/300
# 42/42 [==============================] - 2s 48ms/step - loss: 4.0809
# Epoch 105/300
# 42/42 [==============================] - 2s 55ms/step - loss: 4.7546
# Epoch 106/300
# 42/42 [==============================] - 2s 40ms/step - loss: 4.0292
# Epoch 107/300
# 42/42 [==============================] - 2s 38ms/step - loss: 3.9377
# Epoch 108/300
# 42/42 [==============================] - 2s 47ms/step - loss: 3.8408
# Epoch 109/300
# 42/42 [==============================] - 2s 60ms/step - loss: 4.5942
# Epoch 110/300
# 42/42 [==============================] - 2s 48ms/step - loss: 3.9326
# Epoch 111/300
# 42/42 [==============================] - 3s 62ms/step - loss: 3.8616
# Epoch 112/300
# 42/42 [==============================] - 2s 47ms/step - loss: 3.8181
# Epoch 113/300
# 42/42 [==============================] - 2s 40ms/step - loss: 4.1686
# Epoch 114/300
# 42/42 [==============================] - 2s 55ms/step - loss: 3.8243
# Epoch 115/300
# 42/42 [==============================] - 2s 43ms/step - loss: 4.4048
# Epoch 116/300
# 42/42 [==============================] - 1s 26ms/step - loss: 4.0702
# Epoch 117/300
# 42/42 [==============================] - 2s 47ms/step - loss: 4.2771
# Epoch 118/300
# 42/42 [==============================] - 2s 39ms/step - loss: 4.6751
# Epoch 119/300
# 42/42 [==============================] - 2s 54ms/step - loss: 3.7753
# Epoch 120/300
# 42/42 [==============================] - 2s 40ms/step - loss: 3.9050
# Epoch 121/300
# 42/42 [==============================] - 3s 61ms/step - loss: 4.0163
# Epoch 122/300
# 42/42 [==============================] - 3s 61ms/step - loss: 4.1750
# Epoch 123/300
# 42/42 [==============================] - 2s 49ms/step - loss: 3.8634
# Epoch 124/300
# 42/42 [==============================] - 1s 29ms/step - loss: 3.8929
# Epoch 125/300
# 42/42 [==============================] - 1s 34ms/step - loss: 4.5175
# Epoch 126/300
# 42/42 [==============================] - 2s 48ms/step - loss: 4.1573
# Epoch 127/300
# 42/42 [==============================] - 2s 49ms/step - loss: 4.0960
# Epoch 128/300
# 42/42 [==============================] - 2s 47ms/step - loss: 4.4149
# Epoch 129/300
# 42/42 [==============================] - 2s 52ms/step - loss: 4.0528
# Epoch 130/300
# 42/42 [==============================] - 2s 37ms/step - loss: 4.1491
# Epoch 131/300
# 42/42 [==============================] - 3s 72ms/step - loss: 4.2748
# Epoch 132/300
# 42/42 [==============================] - 1s 31ms/step - loss: 4.3433
# Epoch 133/300
# 42/42 [==============================] - 1s 27ms/step - loss: 4.7240
# Epoch 134/300
# 42/42 [==============================] - 1s 34ms/step - loss: 3.7572
# Epoch 135/300
# 42/42 [==============================] - 2s 56ms/step - loss: 3.8579
# Epoch 136/300
# 42/42 [==============================] - 1s 23ms/step - loss: 3.8814
# Epoch 137/300
# 42/42 [==============================] - 2s 51ms/step - loss: 3.9166
# Epoch 138/300
# 42/42 [==============================] - 1s 31ms/step - loss: 3.9948
# Epoch 139/300
# 42/42 [==============================] - 1s 27ms/step - loss: 4.3978
# Epoch 140/300
# 42/42 [==============================] - 3s 59ms/step - loss: 4.1079
# Epoch 141/300
# 42/42 [==============================] - 3s 61ms/step - loss: 4.0945
# Epoch 142/300
# 42/42 [==============================] - 2s 34ms/step - loss: 4.6252
# Epoch 143/300
# 42/42 [==============================] - 1s 13ms/step - loss: 4.3183
# Epoch 144/300
# 42/42 [==============================] - 2s 38ms/step - loss: 3.9146
# Epoch 145/300
# 42/42 [==============================] - 2s 44ms/step - loss: 3.7824
# Epoch 146/300
# 42/42 [==============================] - 1s 31ms/step - loss: 4.3152
# Epoch 147/300
# 42/42 [==============================] - 3s 67ms/step - loss: 4.1130
# Epoch 148/300
# 42/42 [==============================] - 2s 53ms/step - loss: 3.9914
# Epoch 149/300
# 42/42 [==============================] - 3s 68ms/step - loss: 3.9903
# Epoch 150/300
# 42/42 [==============================] - 3s 62ms/step - loss: 4.1356
# Epoch 151/300
# 42/42 [==============================] - 2s 43ms/step - loss: 4.0366
# Epoch 152/300
# 42/42 [==============================] - 1s 32ms/step - loss: 4.0651
# Epoch 153/300
# 42/42 [==============================] - 3s 77ms/step - loss: 4.2464
# Epoch 154/300
# 42/42 [==============================] - 3s 63ms/step - loss: 3.8453
# Epoch 155/300
# 42/42 [==============================] - 3s 73ms/step - loss: 3.9202
# Epoch 156/300
# 42/42 [==============================] - 2s 41ms/step - loss: 3.8749
# Epoch 157/300
# 42/42 [==============================] - 3s 68ms/step - loss: 3.8198
# Epoch 158/300
# 42/42 [==============================] - 3s 73ms/step - loss: 3.8829
# Epoch 159/300
# 42/42 [==============================] - 3s 67ms/step - loss: 3.7459
# Epoch 160/300
# 42/42 [==============================] - 1s 24ms/step - loss: 3.8864
# Epoch 161/300
# 42/42 [==============================] - 2s 39ms/step - loss: 3.7787
# Epoch 162/300
# 42/42 [==============================] - 2s 59ms/step - loss: 4.0454
# Epoch 163/300
# 42/42 [==============================] - 1s 31ms/step - loss: 3.8640
# Epoch 164/300
# 42/42 [==============================] - 2s 48ms/step - loss: 4.1955
# Epoch 165/300
# 42/42 [==============================] - 3s 66ms/step - loss: 3.8441
# Epoch 166/300
# 42/42 [==============================] - 1s 13ms/step - loss: 3.9863
# Epoch 167/300
# 42/42 [==============================] - 2s 43ms/step - loss: 4.1092
# Epoch 168/300
# 42/42 [==============================] - 1s 34ms/step - loss: 3.9342
# Epoch 169/300
# 42/42 [==============================] - 2s 43ms/step - loss: 3.9197
# Epoch 170/300
# 42/42 [==============================] - 2s 44ms/step - loss: 4.1187
# Epoch 171/300
# 42/42 [==============================] - 2s 58ms/step - loss: 4.1277
# Epoch 172/300
# 42/42 [==============================] - 3s 61ms/step - loss: 3.9463
# Epoch 173/300
# 42/42 [==============================] - 3s 75ms/step - loss: 3.9141
# Epoch 174/300
# 42/42 [==============================] - 3s 65ms/step - loss: 4.0859
# Epoch 175/300
# 42/42 [==============================] - 3s 67ms/step - loss: 4.1338
# Epoch 176/300
# 42/42 [==============================] - 1s 21ms/step - loss: 4.0070
# Epoch 177/300
# 42/42 [==============================] - 1s 19ms/step - loss: 3.8527
# Epoch 178/300
# 42/42 [==============================] - 2s 55ms/step - loss: 3.9204
# Epoch 179/300
# 42/42 [==============================] - 3s 64ms/step - loss: 4.0087
# Epoch 180/300
# 42/42 [==============================] - 3s 63ms/step - loss: 4.1365
# Epoch 181/300
# 42/42 [==============================] - 2s 47ms/step - loss: 3.7287
# Epoch 182/300
# 42/42 [==============================] - 2s 48ms/step - loss: 4.4155
# Epoch 183/300
# 42/42 [==============================] - 1s 26ms/step - loss: 3.8276
# Epoch 184/300
# 42/42 [==============================] - 2s 45ms/step - loss: 4.1180
# Epoch 185/300
# 42/42 [==============================] - 1s 17ms/step - loss: 4.0379
# Epoch 186/300
# 42/42 [==============================] - 3s 65ms/step - loss: 4.0971
# Epoch 187/300
# 42/42 [==============================] - 2s 55ms/step - loss: 3.7637
# Epoch 188/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.9558
# Epoch 189/300
# 42/42 [==============================] - 2s 59ms/step - loss: 3.8894
# Epoch 190/300
# 42/42 [==============================] - 2s 48ms/step - loss: 3.8957
# Epoch 191/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.9390
# Epoch 192/300
# 42/42 [==============================] - 3s 65ms/step - loss: 4.2267
# Epoch 193/300
# 42/42 [==============================] - 3s 80ms/step - loss: 4.0226
# Epoch 194/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.9263
# Epoch 195/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.8333
# Epoch 196/300
# 42/42 [==============================] - 3s 66ms/step - loss: 3.7707
# Epoch 197/300
# 42/42 [==============================] - 3s 62ms/step - loss: 4.0296
# Epoch 198/300
# 42/42 [==============================] - 3s 69ms/step - loss: 3.8985
# Epoch 199/300
# 42/42 [==============================] - 3s 70ms/step - loss: 3.8229
# Epoch 200/300
# 42/42 [==============================] - 3s 72ms/step - loss: 3.6907
# Epoch 201/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.8581
# Epoch 202/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.8104
# Epoch 203/300
# 42/42 [==============================] - 3s 79ms/step - loss: 4.4473
# Epoch 204/300
# 42/42 [==============================] - 4s 86ms/step - loss: 4.0349
# Epoch 205/300
# 42/42 [==============================] - 3s 83ms/step - loss: 4.0567
# Epoch 206/300
# 42/42 [==============================] - 4s 88ms/step - loss: 3.7372
# Epoch 207/300
# 42/42 [==============================] - 4s 87ms/step - loss: 4.3471
# Epoch 208/300
# 42/42 [==============================] - 3s 83ms/step - loss: 4.0101
# Epoch 209/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.9451
# Epoch 210/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.6876
# Epoch 211/300
# 42/42 [==============================] - 3s 74ms/step - loss: 3.8081
# Epoch 212/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.9528
# Epoch 213/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.7165
# Epoch 214/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7476
# Epoch 215/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.8107
# Epoch 216/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.7731
# Epoch 217/300
# 42/42 [==============================] - 3s 81ms/step - loss: 3.7168
# Epoch 218/300
# 42/42 [==============================] - 3s 80ms/step - loss: 4.0368
# Epoch 219/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.8811
# Epoch 220/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.9454
# Epoch 221/300
# 42/42 [==============================] - 3s 78ms/step - loss: 4.1165
# Epoch 222/300
# 42/42 [==============================] - 4s 84ms/step - loss: 3.9214
# Epoch 223/300
# 42/42 [==============================] - 3s 77ms/step - loss: 4.0654
# Epoch 224/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7813
# Epoch 225/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.9523
# Epoch 226/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.7636
# Epoch 227/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.8508
# Epoch 228/300
# 42/42 [==============================] - 3s 75ms/step - loss: 3.9413
# Epoch 229/300
# 42/42 [==============================] - 3s 78ms/step - loss: 3.9823
# Epoch 230/300
# 42/42 [==============================] - 3s 74ms/step - loss: 4.3814
# Epoch 231/300
# 42/42 [==============================] - 3s 81ms/step - loss: 3.8999
# Epoch 232/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7260
# Epoch 233/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.9995
# Epoch 234/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.9563
# Epoch 235/300
# 42/42 [==============================] - 3s 81ms/step - loss: 3.7004
# Epoch 236/300
# 42/42 [==============================] - 4s 86ms/step - loss: 3.7003
# Epoch 237/300
# 42/42 [==============================] - 3s 70ms/step - loss: 3.8331
# Epoch 238/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.8805
# Epoch 239/300
# 42/42 [==============================] - 4s 84ms/step - loss: 3.7475
# Epoch 240/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.7293
# Epoch 241/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.8959
# Epoch 242/300
# 42/42 [==============================] - 3s 67ms/step - loss: 3.7359
# Epoch 243/300
# 42/42 [==============================] - 3s 69ms/step - loss: 3.7867
# Epoch 244/300
# 42/42 [==============================] - 4s 85ms/step - loss: 3.7241
# Epoch 245/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.8579
# Epoch 246/300
# 42/42 [==============================] - 4s 86ms/step - loss: 3.9570
# Epoch 247/300
# 42/42 [==============================] - 4s 94ms/step - loss: 3.8921
# Epoch 248/300
# 42/42 [==============================] - 4s 93ms/step - loss: 3.9676
# Epoch 249/300
# 42/42 [==============================] - 4s 88ms/step - loss: 3.6738
# Epoch 250/300
# 42/42 [==============================] - 3s 72ms/step - loss: 3.9579
# Epoch 251/300
# 42/42 [==============================] - 3s 76ms/step - loss: 3.8723
# Epoch 252/300
# 42/42 [==============================] - 3s 70ms/step - loss: 3.7652
# Epoch 253/300
# 42/42 [==============================] - 3s 71ms/step - loss: 3.9171
# Epoch 254/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.7402
# Epoch 255/300
# 42/42 [==============================] - 3s 80ms/step - loss: 4.0190
# Epoch 256/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.9414
# Epoch 257/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.6762
# Epoch 258/300
# 42/42 [==============================] - 3s 79ms/step - loss: 3.8363
# Epoch 259/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7359
# Epoch 260/300
# 42/42 [==============================] - 3s 76ms/step - loss: 4.0288
# Epoch 261/300
# 42/42 [==============================] - 3s 78ms/step - loss: 4.0291
# Epoch 262/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7350
# Epoch 263/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.6505
# Epoch 264/300
# 42/42 [==============================] - 3s 62ms/step - loss: 3.7420
# Epoch 265/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.6609
# Epoch 266/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.7375
# Epoch 267/300
# 42/42 [==============================] - 2s 50ms/step - loss: 3.9593
# Epoch 268/300
# 42/42 [==============================] - 2s 59ms/step - loss: 3.9091
# Epoch 269/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.9074
# Epoch 270/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.8907
# Epoch 271/300
# 42/42 [==============================] - 3s 73ms/step - loss: 3.8830
# Epoch 272/300
# 42/42 [==============================] - 3s 82ms/step - loss: 3.9812
# Epoch 273/300
# 42/42 [==============================] - 3s 76ms/step - loss: 3.9707
# Epoch 274/300
# 42/42 [==============================] - 3s 81ms/step - loss: 3.7823
# Epoch 275/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.8394
# Epoch 276/300
# 42/42 [==============================] - 3s 66ms/step - loss: 3.7277
# Epoch 277/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.7185
# Epoch 278/300
# 42/42 [==============================] - 2s 58ms/step - loss: 3.6833
# Epoch 279/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.8946
# Epoch 280/300
# 42/42 [==============================] - 4s 84ms/step - loss: 3.8441
# Epoch 281/300
# 42/42 [==============================] - 3s 80ms/step - loss: 3.9097
# Epoch 282/300
# 42/42 [==============================] - 4s 85ms/step - loss: 3.8606
# Epoch 283/300
# 42/42 [==============================] - 3s 77ms/step - loss: 3.9630
# Epoch 284/300
# 42/42 [==============================] - 4s 104ms/step - loss: 3.8408
# Epoch 285/300
# 42/42 [==============================] - 4s 92ms/step - loss: 3.8563
# Epoch 286/300
# 42/42 [==============================] - 4s 90ms/step - loss: 3.8105
# Epoch 287/300
# 42/42 [==============================] - 3s 69ms/step - loss: 3.7592
# Epoch 288/300
# 42/42 [==============================] - 3s 76ms/step - loss: 3.6835
# Epoch 289/300
# 42/42 [==============================] - 2s 57ms/step - loss: 3.8552
# Epoch 290/300
# 42/42 [==============================] - 3s 61ms/step - loss: 3.8265
# Epoch 291/300
# 42/42 [==============================] - 3s 60ms/step - loss: 4.0266
# Epoch 292/300
# 42/42 [==============================] - 2s 49ms/step - loss: 3.7295
# Epoch 293/300
# 42/42 [==============================] - 2s 59ms/step - loss: 3.6959
# Epoch 294/300
# 42/42 [==============================] - 2s 50ms/step - loss: 3.9807
# Epoch 295/300
# 42/42 [==============================] - 3s 60ms/step - loss: 4.0193
# Epoch 296/300
# 42/42 [==============================] - 2s 56ms/step - loss: 3.7472
# Epoch 297/300
# 42/42 [==============================] - 2s 58ms/step - loss: 3.8264
# Epoch 298/300
# 42/42 [==============================] - 2s 55ms/step - loss: 3.6770
# Epoch 299/300
# 42/42 [==============================] - 2s 50ms/step - loss: 3.9860
# Epoch 300/300
# 42/42 [==============================] - 2s 59ms/step - loss: 3.8669

# %%
# Mostramos la evolucióón del entrenamiento
loss_ev = history.history['loss']

import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(loss_ev)

# %%
# Evaluamos el modelo en train
score = model.evaluate(XX_tr, YY_tr, verbose=0)
score
# Out:
# 3.573000431060791

# %%
# Predecimos con los datos de train
y_hat = model.predict(XX_tr)
np.mean(abs(y_hat[:,0]-YY_tr))
# Out:
# 42/42 [==============================] - 0s 2ms/step
# 3.5730001640749722

# %%
y_hat.shape
# Out:
# (1331, 1)

# %%
# Mostramos las predicciones
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(y_hat, label='datos')
plt.plot(YY_tr, label='predicciones')
plt.legend()

# %% [markdown]
# TEST

# %%
# Predecimos en test
y_hat = model.predict(XX_ts)
# mostramos el error
np.mean(abs(y_hat[:,0]-YY_ts))
# Out:
# 42/42 [==============================] - 0s 3ms/step
# 6.402509553608143

# %%
# Mostramos las predicciones
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(y_hat, label='datos')
plt.plot(YY_ts, label='predicciones')
plt.legend()

# %%
# Estas son las diferencias
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot(y_hat[:,0]-YY_ts, label='NN')
plt.legend()
