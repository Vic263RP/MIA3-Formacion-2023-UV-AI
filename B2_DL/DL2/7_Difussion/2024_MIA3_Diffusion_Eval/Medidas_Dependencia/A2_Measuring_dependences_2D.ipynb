# %% [markdown]
# # EJEMPLO
# medidas de dependencia en datos 2D con:
# - correlación
# - HSIC, nHSIC, linHSIC
# - MI (con RBIG)

# %%
# Importamos las librerias necesarias
import tensorflow.keras as keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
from tqdm.notebook import trange
import scipy

# %% [markdown]
# # Definición de las medidas

# %% [markdown]
# ### HSIC y nHSIC en TF
# Code adapted from:
# https://github.com/romain-lopez/HCV/blob/master/hcv.py

# %%
from scipy.special import gamma
import tensorflow as tf
import numpy as np

def bandwidth(d):
    """
    in the case of Gaussian random variables and the use of a RBF kernel,
    this can be used to select the bandwidth according to the median heuristic
    """
    gz = 2 * gamma(0.5 * (d+1)) / gamma(0.5 * d)
    return 1. / (2. * gz**2)

def K(x1, x2, gamma=1.):
    dist_table = tf.expand_dims(x1, 0) - tf.expand_dims(x2, 1)
    return tf.transpose(tf.exp(-gamma * tf.reduce_sum(dist_table **2, axis=2)))


def hsic(z, s):
    s = tf.cast(s,'float32')
    s = tf.convert_to_tensor(s)

    z = tf.cast(z,'float32')
    z = tf.convert_to_tensor(z)

    # use a gaussian RBF for every variable

    d_z = z.get_shape().as_list()[1]
    d_s = s.get_shape().as_list()[1]

    zz = K(z, z, gamma= bandwidth(d_z))
    ss = K(s, s, gamma= bandwidth(d_s))


    hsic = 0
    hsic += tf.reduce_mean(zz * ss)
    hsic += tf.reduce_mean(zz) * tf.reduce_mean(ss)
    hsic -= 2 * tf.reduce_mean( tf.reduce_mean(zz, axis=1) * tf.reduce_mean(ss, axis=1) )

    return tf.sqrt(hsic)

def nhsic(z, s):
    s = tf.cast(s,'float32')
    s = tf.convert_to_tensor(s)

    z = tf.cast(z,'float32')
    z = tf.convert_to_tensor(z)
    # use a gaussian RBF for every variable

    d_z = z.get_shape().as_list()[1]
    d_s = s.get_shape().as_list()[1]

    K1 = K(z, z, gamma= bandwidth(d_z))
    K2 = K(s, s, gamma= bandwidth(d_s))

    return tf.reduce_sum(K1 * K2) / tf.norm(K1) / tf.norm(K2)

# %% [markdown]
# ### Correlación de Pearson en TF

# %%
def pearson_r(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = tf.reduce_mean(x)
    my = tf.reduce_mean(y)
    xm, ym = x - mx, y - my
    t1_norm = tf.nn.l2_normalize(xm)
    t2_norm = tf.nn.l2_normalize(ym)
    cosine_loss = tf.keras.losses.CosineSimilarity()
    cosine = -cosine_loss(t1_norm, t2_norm)
    return cosine

# %% [markdown]
# ### RBIG (no en TF)

# %%
# !pip install "git+https://github.com/IPL-UV/rbig.git"
# Out:
# Collecting git+https://github.com/IPL-UV/rbig.git
#   Cloning https://github.com/IPL-UV/rbig.git to /tmp/pip-req-build-4ijhn98f
#   Running command git clone --filter=blob:none --quiet https://github.com/IPL-UV/rbig.git /tmp/pip-req-build-4ijhn98f
#   Resolved https://github.com/IPL-UV/rbig.git to commit a9124fc07d8e851833802d604fe552b6327ab980
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (1.2.2)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (5.2.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (0.13.5)
# Collecting python-picard (from py-rbig==0.0.1)
#   Downloading python_picard-0.7-py3-none-any.whl (16 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (0.12.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (7.7.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (5.5.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from py-rbig==0.0.1) (4.65.0)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy->py-rbig==0.0.1) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->py-rbig==0.0.1) (6.0)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy->py-rbig==0.0.1) (23.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->py-rbig==0.0.1) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->py-rbig==0.0.1) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->py-rbig==0.0.1) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->py-rbig==0.0.1) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->py-rbig==0.0.1) (6.3.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->py-rbig==0.0.1) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->py-rbig==0.0.1) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->py-rbig==0.0.1) (2.8.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from python-picard->py-rbig==0.0.1) (2.8.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->py-rbig==0.0.1) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->py-rbig==0.0.1) (3.1.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn->py-rbig==0.0.1) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->py-rbig==0.0.1) (0.5.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn->py-rbig==0.0.1) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels->py-rbig==0.0.1) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (6.4.8)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->py-rbig==0.0.1) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->py-rbig==0.0.1) (23.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->py-rbig==0.0.1) (3.8.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (3.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (21.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (5.9.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->py-rbig==0.0.1) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (2.1.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->py-rbig==0.0.1) (2.21)
# Building wheels for collected packages: py-rbig
#   Building wheel for py-rbig (setup.py) ... done
#   Created wheel for py-rbig: filename=py_rbig-0.0.1-py3-none-any.whl size=17469 sha256=905e816addd1552333ef91bee0ccca6be29c853f2cbbba814cbe47ad4465f98f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1fva_yop/wheels/49/be/80/0285fa4ec7c96e2c9a8c8bcb0cd0330a26e0ce7fbb4b5afc19
# Successfully built py-rbig
# Installing collected packages: jedi, python-picard, py-rbig
# Successfully installed jedi-0.18.2 py-rbig-0.0.1 python-picard-0.7

# %%
# !pip install python-picard
# Out:
# Requirement already satisfied: python-picard in /usr/local/lib/python3.10/dist-packages (0.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-picard) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-picard) (1.10.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from python-picard) (2.8.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-picard) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-picard) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-picard) (3.1.0)

# %%
from rbig._src.mutual_info import MutualInfoRBIG
# Out:
# /usr/local/lib/python3.10/dist-packages/rbig/_src/training.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange

# %%
rbig_model = MutualInfoRBIG()

# %% [markdown]
# # Data Toy non-linear regression

# %%
# number of data points
N = 1000

x_train = np.random.randn(N,2)
y_train = x_train.copy()
y_train[:,0] = (2 * x_train[:,0])**2 + np.random.randn(N,)
y_train[:,1] = (2 * x_train[:,1])**2 + np.random.randn(N,)

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x_train[:,0],y_train[:,0],'.')

plt.subplot(2,2,2)
plt.plot(x_train[:,0],y_train[:,1],'.')

plt.subplot(2,2,3)
plt.plot(x_train[:,1],y_train[:,0],'.')

plt.subplot(2,2,4)
plt.plot(x_train[:,1],y_train[:,1],'.')

# %%
y_train = y_train.astype(np.float32)
x_train = x_train.astype(np.float32)

# %% [markdown]
# # Aplicación de las medidas

# %% [markdown]
# Correlación

# %%
# pearson correlation per dimension
C_xx = x_train.T @ x_train
C_yy = y_train.T @ y_train
C_xy = x_train.T @ y_train
hs_score_xy = np.linalg.norm(C_xy, ord='fro')
hs_score_xy_norm = hs_score_xy/(np.linalg.norm(C_xx, ord='fro')*np.linalg.norm(C_yy, ord='fro'))

corr_spearman_scipy = scipy.stats.spearmanr(x_train,y_train)[0]
hs_sp_score = np.linalg.norm(corr_spearman_scipy, ord='fro')

# %% [markdown]
# HSIC

# %%
C_xy = c_xy = x_train.T @ y_train
hsic_lin = np.sqrt(np.sum(C_xy * C_xy))

# %%
hsic_tf = hsic(x_train,y_train).numpy()
nhsic_tf = nhsic(x_train,y_train).numpy()

# %% [markdown]
# RBIG

# %%
rbig_model.fit(x_train,y_train);
mi_rbig = rbig_model.mutual_info() * np.log(2)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # Results

# %%
print('hs score xy: ' + str(hs_score_xy))
print('hs score xy norm: ' + str(hs_score_xy_norm))
print('hs score xy spearman: ' + str(hs_sp_score))
print('hsic lin: ' + str(hsic_lin))
print('hsic: ' + str(hsic_tf))
print('nhsic: ' + str(nhsic_tf))
print('MI (RBIG): ' + str(mi_rbig))
# Out:
# hs score xy: 1006.6322
# hs score xy norm: 9.3996005e-06
# hs score xy spearman: 2.0061033780460913
# hsic lin: 1006.6322
# hsic: 0.073298216
# nhsic: 0.565213
# MI (RBIG): 0.41206073431997664

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x_train[:,0],y_train[:,0],'.')

plt.subplot(2,2,2)
plt.plot(x_train[:,0],y_train[:,1],'.')

plt.subplot(2,2,3)
plt.plot(x_train[:,1],y_train[:,0],'.')

plt.subplot(2,2,4)
plt.plot(x_train[:,1],y_train[:,1],'.')

# %% [markdown]
# # Data Toy non-linear regression

# %%
# number of data points
N = 1000

x_train = np.random.randn(N,2)
y_train = x_train.copy()
y_train[:,0] = (2 * x_train[:,0])**2 + 3*np.random.randn(N,)
y_train[:,1] = (2 * x_train[:,1])**2 + 3*np.random.randn(N,)

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x_train[:,0],y_train[:,0],'.')

plt.subplot(2,2,2)
plt.plot(x_train[:,0],y_train[:,1],'.')

plt.subplot(2,2,3)
plt.plot(x_train[:,1],y_train[:,0],'.')

plt.subplot(2,2,4)
plt.plot(x_train[:,1],y_train[:,1],'.')

# %%
y_train = y_train.astype(np.float32)
x_train = x_train.astype(np.float32)

# %% [markdown]
# # Aplicación de las medidas

# %% [markdown]
# Correlación

# %%
# pearson correlation per dimension
C_xx = x_train.T @ x_train
C_yy = y_train.T @ y_train
C_xy = x_train.T @ y_train
hs_score_xy = np.linalg.norm(C_xy, ord='fro')
hs_score_xy_norm = hs_score_xy/(np.linalg.norm(C_xx, ord='fro')*np.linalg.norm(C_yy, ord='fro'))

corr_spearman_scipy = scipy.stats.spearmanr(x_train,y_train)[0]
hs_sp_score = np.linalg.norm(corr_spearman_scipy, ord='fro')

# %% [markdown]
# HSIC

# %%
C_xy = c_xy = x_train.T @ y_train
hsic_lin = np.sqrt(np.sum(C_xy * C_xy))

# %%
hsic_tf = hsic(x_train,y_train).numpy()
nhsic_tf = nhsic(x_train,y_train).numpy()

# %% [markdown]
# RBIG

# %%
rbig_model.fit(x_train,y_train);
mi_rbig = rbig_model.mutual_info() * np.log(2)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # Results

# %%
print('hs score xy: ' + str(hs_score_xy))
print('hs score xy norm: ' + str(hs_score_xy_norm))
print('hs score xy spearman: ' + str(hs_sp_score))
print('hsic lin: ' + str(hsic_lin))
print('hsic: ' + str(hsic_tf))
print('nhsic: ' + str(nhsic_tf))
print('MI (RBIG): ' + str(mi_rbig))

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x_train[:,0],y_train[:,0],'.')

plt.subplot(2,2,2)
plt.plot(x_train[:,0],y_train[:,1],'.')

plt.subplot(2,2,3)
plt.plot(x_train[:,1],y_train[:,0],'.')

plt.subplot(2,2,4)
plt.plot(x_train[:,1],y_train[:,1],'.')
