# %% [markdown]
# # **PCA y Clustering en series temporales financieras**

# %%
COLAB = True

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Carga de datos**

# %%
if COLAB:
  # !mkdir datasets
  aux = "'https://docs.google.com/uc?export=download&id=1GWhI2wH1Ka_wFqsGAiZ-c8U91PYxewBN&confirm=t'"
  # !wget $aux -O ./datasets/financial_series.csv

df = pd.read_csv('./datasets/financial_series.csv')
df.head(3)
# Out:
# --2023-11-04 11:00:07--  https://docs.google.com/uc?export=download&id=1GWhI2wH1Ka_wFqsGAiZ-c8U91PYxewBN&confirm=t
# Resolving docs.google.com (docs.google.com)... 74.125.203.138, 74.125.203.101, 74.125.203.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.203.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0g-8k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kjoc6crg3ndo7utcf0nq66frub7s7qdk/1699095600000/17112108692206476645/*/1GWhI2wH1Ka_wFqsGAiZ-c8U91PYxewBN?e=download&uuid=b5b4dbe6-8d79-48aa-a52d-649e7fac0f2b [following]
# Warning: wildcards not supported in HTTP.
# --2023-11-04 11:00:08--  https://doc-0g-8k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kjoc6crg3ndo7utcf0nq66frub7s7qdk/1699095600000/17112108692206476645/*/1GWhI2wH1Ka_wFqsGAiZ-c8U91PYxewBN?e=download&uuid=b5b4dbe6-8d79-48aa-a52d-649e7fac0f2b
# Resolving doc-0g-8k-docs.googleusercontent.com (doc-0g-8k-docs.googleusercontent.com)... 173.194.174.132, 2404:6800:4008:c1b::84
# Connecting to doc-0g-8k-docs.googleusercontent.com (doc-0g-8k-docs.googleusercontent.com)|173.194.174.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 236036 (231K) [text/csv]
# Saving to: ‘./datasets/financial_series.csv’
#
# ./datasets/financia 100%[===================>] 230.50K  --.-KB/s    in 0.002s
#
# 2023-11-04 11:00:08 (90.9 MB/s) - ‘./datasets/financial_series.csv’ saved [236036/236036]
#          Date  Daimler DAX30  Deutsche Borse DAX30  Deutsche Bank DAX30  \
# 0  2011-01-09          54.53                 53.30               41.010
# 1  2011-01-16          55.95                 56.89               43.260
# 2  2011-01-23          54.78                 57.30               44.275
#
#    Deutsche Post DAX30  Deutsche Telekom DAX30  EON DAX30  Fresenius DAX30  \
# 0               13.025                   9.857     22.655            62.00
# 1               13.350                   9.633     23.840            60.61
# 2               13.565                   9.940     25.070            59.90
#
#    Heidelberg Cement DAX30  Henkel DAX30  ...  Microsoft NASDAQ  \
# 0                   45.455        45.980  ...         28.600000
# 1                   47.595        47.305  ...         28.299999
# 2                   47.640        44.700  ...         28.020000
#
#    Procter Gamble NASDAQ  Cisco NASDAQ  American Express NASDAQ  \
# 0              64.500000         20.97                    44.36
# 1              65.529999         21.21                    46.25
# 2              65.910004         20.72                    46.00
#
#    Boeing NASDAQ  Caterpillar NASDAQ  Walt Disney NASDAQ  \
# 0          69.38               93.73               39.45
# 1          70.07               94.01               39.29
# 2          71.68               92.75               39.74
#
#    General Electric NASDAQ  Goldman Sachs NASDAQ  JP Morgan Chase NASDAQ
# 0                    18.43                170.69                   43.64
# 1                    18.82                175.00                   44.91
# 2                    19.74                166.20                   45.29
#
# [3 rows x 54 columns]

# %%
df.shape
# Out:
# (277, 54)

# %%
df.T
# Out:
#                                                0           1           2    \
# Date                                    2011-01-09  2011-01-16  2011-01-23
# Daimler DAX30                                54.53       55.95       54.78
# Deutsche Borse DAX30                          53.3       56.89        57.3
# Deutsche Bank DAX30                          41.01       43.26      44.275
# Deutsche Post DAX30                         13.025       13.35      13.565
# Deutsche Telekom DAX30                       9.857       9.633        9.94
# EON DAX30                                   22.655       23.84       25.07
# Fresenius DAX30                               62.0       60.61        59.9
# Heidelberg Cement DAX30                     45.455      47.595       47.64
# Henkel DAX30                                 45.98      47.305        44.7
# Infineon DAX30                               7.034        7.34        7.27
# Lufthansa DAX30                             17.255       16.97       15.81
# Linde DAX30                                  109.7       107.9       105.3
# Lanxess DAX30                                55.65       55.12       53.38
# Merck DAX30                                  61.03       59.98       60.41
# Munchener Ruck DAX30                        113.35      112.25      115.45
# RWE DAX30                                    50.96       53.27       55.26
# SAP DAX30                                   38.075       40.18       40.13
# KS DAX30                                     56.31        55.5       52.55
# Siemens DAX30                                89.72       91.07       92.35
# Thyssen Krupp DAX30                          30.37        30.7       29.95
# Volkswagen Group DAX30                      127.85      125.75       114.0
# Adidas DAX30                                 47.59       46.97       44.84
# Beiersdorf DAX30                              42.5        40.9       40.19
# Continental DAX30                            58.01        60.0       58.23
# Commerzbank DAX30                          3.29341      3.2676     3.39372
# Allianz DAX30                                90.65        93.7       97.91
# BASF DAX30                                   57.38        57.6        56.3
# Bayer DAX30                                  55.71       55.16       54.21
# BMW DAX30                                     59.4       58.76       55.65
# Coca Cola NASDAQ                             31.46       31.56       31.38
# McDonalds NASDAQ                             74.37       74.06       75.01
# 3m NASDAQ                                    86.23        88.1       89.29
# Nike NASDAQ                                  20.88       21.02       20.58
# Pfizer NASDAQ                                18.34       18.34       18.36
# The Travelers Companies NASDAQ               53.33       54.63        55.0
# United Technologies Corporation NASDAQ       79.08       79.08        80.2
# Visa NASDAQ                                  18.24       17.78       17.54
# Verizon Communications NASDAQ                35.93       35.46       34.95
# WalMart NASDAQ                               54.08       54.81       55.73
# Chevron NASDAQ                           91.190002   92.830002   93.779999
# Home Depot NASDAQ                        34.380001   35.889999   36.509998
# IBM NASDAQ                              147.929993       150.0       155.5
# Intel NASDAQ                                 20.66       21.08       20.82
# Microsoft NASDAQ                              28.6   28.299999       28.02
# Procter Gamble NASDAQ                         64.5   65.529999   65.910004
# Cisco NASDAQ                                 20.97       21.21       20.72
# American Express NASDAQ                      44.36       46.25        46.0
# Boeing NASDAQ                                69.38       70.07       71.68
# Caterpillar NASDAQ                           93.73       94.01       92.75
# Walt Disney NASDAQ                           39.45       39.29       39.74
# General Electric NASDAQ                      18.43       18.82       19.74
# Goldman Sachs NASDAQ                        170.69       175.0       166.2
# JP Morgan Chase NASDAQ                       43.64       44.91       45.29
#
#                                                3           4           5    \
# Date                                    2011-01-30  2011-02-06  2011-02-13
# Daimler DAX30                                 54.8       52.69       56.51
# Deutsche Borse DAX30                         56.84       56.86       61.62
# Deutsche Bank DAX30                          43.63      46.235       46.17
# Deutsche Post DAX30                         13.375      13.405        13.6
# Deutsche Telekom DAX30                       9.729      10.065         9.9
# EON DAX30                                    24.45       24.52       24.78
# Fresenius DAX30                               63.5        62.9       62.45
# Heidelberg Cement DAX30                      48.13      47.985       49.55
# Henkel DAX30                                 44.57       44.86      44.465
# Infineon DAX30                               7.735        8.03         8.2
# Lufthansa DAX30                              15.59      15.295       15.63
# Linde DAX30                                 105.35      109.35       109.6
# Lanxess DAX30                                53.59       54.87       56.79
# Merck DAX30                                  61.94       63.82        63.1
# Munchener Ruck DAX30                         114.5       120.2      122.05
# RWE DAX30                                    52.64       53.43       53.47
# SAP DAX30                                    42.15       43.21      44.365
# KS DAX30                                     53.48       57.54       57.84
# Siemens DAX30                                93.79       93.24       94.68
# Thyssen Krupp DAX30                         29.475      30.685       30.29
# Volkswagen Group DAX30                       120.4      115.35       128.2
# Adidas DAX30                                 45.82       46.05       48.52
# Beiersdorf DAX30                             40.08       41.98       41.32
# Continental DAX30                            58.34       58.77       64.27
# Commerzbank DAX30                          3.26642     3.38375     3.38375
# Allianz DAX30                               100.77       105.6       105.1
# BASF DAX30                                   56.86        58.9       57.94
# Bayer DAX30                                  53.77       54.53       55.58
# BMW DAX30                                    57.36       56.64        63.2
# Coca Cola NASDAQ                              31.1       31.28       31.78
# McDonalds NASDAQ                             73.28       74.05       76.14
# 3m NASDAQ                                    87.44       88.29        91.8
# Nike NASDAQ                                  20.36       21.44       21.55
# Pfizer NASDAQ                                18.15        19.3       18.83
# The Travelers Companies NASDAQ               55.81       57.41       58.99
# United Technologies Corporation NASDAQ       81.43       82.52        85.2
# Visa NASDAQ                                  17.36       18.22       18.73
# Verizon Communications NASDAQ                35.63       36.31       36.39
# WalMart NASDAQ                                56.7       56.03       55.69
# Chevron NASDAQ                           93.370003   97.110001   96.449997
# Home Depot NASDAQ                        36.700001   36.799999       37.48
# IBM NASDAQ                              159.210007       164.0  163.850006
# Intel NASDAQ                             21.459999       21.68       21.76
# Microsoft NASDAQ                             27.75       27.77       27.25
# Procter Gamble NASDAQ                    64.199997   63.610001   64.730003
# Cisco NASDAQ                                 20.93       22.05        18.7
# American Express NASDAQ                      43.86       43.82       46.75
# Boeing NASDAQ                                69.23       71.38       72.14
# Caterpillar NASDAQ                           95.68       99.59      103.54
# Walt Disney NASDAQ                           38.85       40.71       43.41
# General Electric NASDAQ                       20.2       20.56       21.33
# Goldman Sachs NASDAQ                        161.77      164.83      166.66
# JP Morgan Chase NASDAQ                       44.54       44.59       46.57
#
#                                                6           7           8    \
# Date                                    2011-02-20  2011-02-27  2011-03-06
# Daimler DAX30                                52.63       51.07      48.235
# Deutsche Borse DAX30                         57.52       55.85       55.75
# Deutsche Bank DAX30                          47.93      46.585      44.885
# Deutsche Post DAX30                         13.825       13.23       12.81
# Deutsche Telekom DAX30                       10.01       9.741       9.709
# EON DAX30                                    24.76      23.685      23.195
# Fresenius DAX30                              62.43       65.74       66.95
# Heidelberg Cement DAX30                       52.6       50.76      49.945
# Henkel DAX30                                  45.3      43.525       45.76
# Infineon DAX30                               8.001       7.777        7.69
# Lufthansa DAX30                               15.7       14.73        14.5
# Linde DAX30                                  112.1       108.5      112.45
# Lanxess DAX30                                56.65       53.03       54.31
# Merck DAX30                                   62.7       65.08       65.79
# Munchener Ruck DAX30                         124.8      120.45       119.2
# RWE DAX30                                    52.56       49.22       47.81
# SAP DAX30                                    44.24       43.33       44.05
# KS DAX30                                     57.43       55.48       56.54
# Siemens DAX30                                 98.0       94.16        95.4
# Thyssen Krupp DAX30                          30.27       29.54        29.8
# Volkswagen Group DAX30                      119.65       119.4       117.1
# Adidas DAX30                                  47.9       46.44       46.68
# Beiersdorf DAX30                             43.45       43.35       42.81
# Continental DAX30                            62.86       59.65        60.1
# Commerzbank DAX30                          3.58497     3.61899     3.68353
# Allianz DAX30                               108.43       102.5       104.4
# BASF DAX30                                   61.35        59.2        60.6
# Bayer DAX30                                   57.0        54.9        57.0
# BMW DAX30                                    60.23        59.0       57.85
# Coca Cola NASDAQ                             32.28       32.16        32.6
# McDonalds NASDAQ                             76.13       74.44       76.03
# 3m NASDAQ                                    92.96       90.25       92.19
# Nike NASDAQ                                   22.2        22.0       22.47
# Pfizer NASDAQ                                19.19       18.86       19.66
# The Travelers Companies NASDAQ               60.92        59.6       59.18
# United Technologies Corporation NASDAQ       85.01       83.37       82.86
# Visa NASDAQ                                  18.96       18.67       18.67
# Verizon Communications NASDAQ                36.62       35.97       36.08
# WalMart NASDAQ                               55.38       51.75       52.07
# Chevron NASDAQ                           98.720001  102.099998      103.75
# Home Depot NASDAQ                            38.48   37.080002   37.220001
# IBM NASDAQ                              164.839996  162.279999  161.830002
# Intel NASDAQ                             22.139999   21.860001   21.559999
# Microsoft NASDAQ                         27.059999   26.549999   25.950001
# Procter Gamble NASDAQ                    64.300003       62.84   62.029999
# Cisco NASDAQ                                 18.85       18.64        18.4
# American Express NASDAQ                      45.53       43.53       43.72
# Boeing NASDAQ                                73.04        72.3        71.8
# Caterpillar NASDAQ                          105.86       102.0      103.04
# Walt Disney NASDAQ                           43.56       42.95       43.55
# General Electric NASDAQ                      21.44       20.82       20.37
# Goldman Sachs NASDAQ                        168.04      165.12       161.0
# JP Morgan Chase NASDAQ                        48.0       46.68       45.52
#
#                                                9    ...         267  \
# Date                                    2011-03-13  ...  2016-04-03
# Daimler DAX30                                47.79  ...       65.88
# Deutsche Borse DAX30                         54.08  ...       74.35
# Deutsche Bank DAX30                          42.73  ...       14.91
# Deutsche Post DAX30                         12.945  ...       23.98
# Deutsche Telekom DAX30                       10.16  ...       15.45
# EON DAX30                                    23.08  ...        8.33
# Fresenius DAX30                              65.23  ...       62.87
# Heidelberg Cement DAX30                       47.0  ...       74.95
# Henkel DAX30                                44.365  ...       95.94
# Infineon DAX30                               7.325  ...       12.57
# Lufthansa DAX30                             14.915  ...       14.05
# Linde DAX30                                  109.9  ...       126.0
# Lanxess DAX30                                51.93  ...       42.97
# Merck DAX30                                  66.47  ...       73.04
# Munchener Ruck DAX30                        111.75  ...       175.8
# RWE DAX30                                   47.925  ...       11.35
# SAP DAX30                                   42.325  ...       70.07
# KS DAX30                                     51.67  ...       19.78
# Siemens DAX30                                91.26  ...       90.81
# Thyssen Krupp DAX30                          28.04  ...       19.16
# Volkswagen Group DAX30                       114.3  ...       107.7
# Adidas DAX30                                 46.08  ...      102.63
# Beiersdorf DAX30                             43.32  ...        78.0
# Continental DAX30                            61.16  ...      194.95
# Commerzbank DAX30                          3.42951  ...       7.619
# Allianz DAX30                                100.0  ...       140.1
# BASF DAX30                                   58.65  ...       64.55
# Bayer DAX30                                   55.1  ...       101.1
# BMW DAX30                                     56.3  ...        77.9
# Coca Cola NASDAQ                              32.4  ...       46.83
# McDonalds NASDAQ                             76.73  ...      127.02
# 3m NASDAQ                                    91.61  ...      167.53
# Nike NASDAQ                                  21.79  ...       61.59
# Pfizer NASDAQ                                19.47  ...       30.04
# The Travelers Companies NASDAQ               58.88  ...       117.4
# United Technologies Corporation NASDAQ       81.28  ...       99.97
# Visa NASDAQ                                  18.13  ...       77.59
# Verizon Communications NASDAQ                35.85  ...       54.01
# WalMart NASDAQ                               52.59  ...       69.06
# Chevron NASDAQ                               99.93  ...   94.260002
# Home Depot NASDAQ                        37.139999  ...  134.850006
# IBM NASDAQ                              162.429993  ...  152.520004
# Intel NASDAQ                             20.870001  ...   32.450001
# Microsoft NASDAQ                             25.68  ...       55.57
# Procter Gamble NASDAQ                    61.490002  ...   83.529999
# Cisco NASDAQ                                 17.95  ...       28.69
# American Express NASDAQ                      44.28  ...        61.1
# Boeing NASDAQ                                71.64  ...      126.96
# Caterpillar NASDAQ                          100.02  ...       76.79
# Walt Disney NASDAQ                           42.93  ...       99.07
# General Electric NASDAQ                      20.36  ...       31.93
# Goldman Sachs NASDAQ                        160.68  ...      159.82
# JP Morgan Chase NASDAQ                       45.74  ...       59.87
#
#                                                268         269         270  \
# Date                                    2016-04-10  2016-04-17  2016-04-24
# Daimler DAX30                                59.62       62.51       63.25
# Deutsche Borse DAX30                         71.68       72.48       75.05
# Deutsche Bank DAX30                          13.99       15.35        16.8
# Deutsche Post DAX30                          24.05       25.23        26.1
# Deutsche Telekom DAX30                       15.11       15.68       15.79
# EON DAX30                                     8.27        8.87        9.31
# Fresenius DAX30                              63.36       64.41       65.26
# Heidelberg Cement DAX30                      74.42       77.87       78.48
# Henkel DAX30                                 98.35      100.05       102.4
# Infineon DAX30                               12.41       12.52       12.49
# Lufthansa DAX30                               13.9       14.19        13.6
# Linde DAX30                                 121.45      131.15       135.6
# Lanxess DAX30                                41.65       44.12       45.72
# Merck DAX30                                   76.6       77.79       81.87
# Munchener Ruck DAX30                         174.8      181.05      182.05
# RWE DAX30                                    11.65       12.13       12.78
# SAP DAX30                                    67.51        69.7       71.24
# KS DAX30                                     18.92       20.21       22.22
# Siemens DAX30                                89.25       92.77       96.29
# Thyssen Krupp DAX30                          18.66       20.51       21.69
# Volkswagen Group DAX30                      103.95      109.65      125.45
# Adidas DAX30                                103.04      104.02       107.5
# Beiersdorf DAX30                              76.7        78.4       80.46
# Continental DAX30                           182.27      192.16       193.8
# Commerzbank DAX30                            7.529       8.313         8.3
# Allianz DAX30                                139.2       147.1       154.9
# BASF DAX30                                   63.55        68.4        70.8
# Bayer DAX30                                  101.8       105.6       110.0
# BMW DAX30                                    74.45        78.4        82.8
# Coca Cola NASDAQ                             46.87        46.1       44.54
# McDonalds NASDAQ                            127.96      127.78       125.5
# 3m NASDAQ                                   166.63      168.78      168.66
# Nike NASDAQ                                  59.42        59.5       59.43
# Pfizer NASDAQ                                 32.5        32.5       33.27
# The Travelers Companies NASDAQ              115.23      116.23      110.84
# United Technologies Corporation NASDAQ      101.32      104.57       105.7
# Visa NASDAQ                                  78.03       80.08       79.11
# Verizon Communications NASDAQ                52.18       51.35       50.55
# WalMart NASDAQ                               68.06       69.06       68.72
# Chevron NASDAQ                           96.330002   97.230003  102.010002
# Home Depot NASDAQ                       133.619995  135.009995  135.660004
# IBM NASDAQ                              149.350006  151.720001       148.5
# Intel NASDAQ                             31.629999   31.459999   31.639999
# Microsoft NASDAQ                         54.419998   55.650002   51.779999
# Procter Gamble NASDAQ                    83.199997   82.300003   80.949997
# Cisco NASDAQ                                 27.69        27.9       28.15
# American Express NASDAQ                       59.5       62.14       65.93
# Boeing NASDAQ                               127.88      131.13      131.05
# Caterpillar NASDAQ                           74.35       79.17       78.32
# Walt Disney NASDAQ                           96.42       98.59      103.77
# General Electric NASDAQ                      30.79       31.03       30.76
# Goldman Sachs NASDAQ                        150.28      158.52      166.75
# JP Morgan Chase NASDAQ                       57.74       61.87       63.97
#
#                                                271         272         273  \
# Date                                    2016-05-01  2016-05-08  2016-05-15
# Daimler DAX30                                60.69        59.4       58.83
# Deutsche Borse DAX30                         71.69       74.03       75.54
# Deutsche Bank DAX30                          16.47       14.74       14.68
# Deutsche Post DAX30                          25.64       25.38       26.86
# Deutsche Telekom DAX30                       15.29        15.0       15.93
# EON DAX30                                     9.01        8.41        8.38
# Fresenius DAX30                              63.52       63.12       64.15
# Heidelberg Cement DAX30                      77.59       76.49       75.18
# Henkel DAX30                                 99.68      100.15       101.5
# Infineon DAX30                               12.43       11.99       12.04
# Lufthansa DAX30                              13.82       12.69       12.69
# Linde DAX30                                  133.4       126.3      126.65
# Lanxess DAX30                                45.67       44.44       42.33
# Merck DAX30                                  82.07       79.04       82.25
# Munchener Ruck DAX30                        161.95       162.6       158.4
# RWE DAX30                                    13.05       11.88       12.35
# SAP DAX30                                    68.32       67.37       68.49
# KS DAX30                                     21.78       22.07       21.25
# Siemens DAX30                                91.12       92.67        93.6
# Thyssen Krupp DAX30                          20.31       19.39       18.68
# Volkswagen Group DAX30                      126.45       121.8       129.2
# Adidas DAX30                                113.18      114.04       109.9
# Beiersdorf DAX30                             79.03       78.42       78.48
# Continental DAX30                           191.96       184.7      189.17
# Commerzbank DAX30                             8.15       7.134       6.991
# Allianz DAX30                                148.4       139.2       137.9
# BASF DAX30                                    72.5        68.5        67.9
# Bayer DAX30                                  101.0        97.5       96.05
# BMW DAX30                                     80.8       75.75        73.6
# Coca Cola NASDAQ                              44.8       45.32       45.35
# McDonalds NASDAQ                            126.49      130.58      128.83
# 3m NASDAQ                                   167.38      168.89      168.32
# Nike NASDAQ                                  58.94       58.43       57.31
# Pfizer NASDAQ                                32.71       33.58       33.19
# The Travelers Companies NASDAQ               109.9      110.45      112.67
# United Technologies Corporation NASDAQ      104.37      101.12      100.27
# Visa NASDAQ                                  77.24       77.72       76.83
# Verizon Communications NASDAQ                50.94       51.12       50.94
# WalMart NASDAQ                               66.87       68.25       64.94
# Chevron NASDAQ                              102.18  101.860001  100.739998
# Home Depot NASDAQ                       133.889999  135.699997  133.130005
# IBM NASDAQ                              145.940002  147.289993  147.720001
# Intel NASDAQ                             30.280001   30.040001       29.91
# Microsoft NASDAQ                         49.869999   50.389999   51.080002
# Procter Gamble NASDAQ                    80.120003   82.129997   81.230003
# Cisco NASDAQ                                 27.49       26.53       26.53
# American Express NASDAQ                      65.43       64.51       64.12
# Boeing NASDAQ                                134.8      133.26      132.12
# Caterpillar NASDAQ                           77.72       73.36       70.07
# Walt Disney NASDAQ                          103.26      105.54      100.52
# General Electric NASDAQ                      30.75       30.12       29.64
# Goldman Sachs NASDAQ                        164.11      158.85      155.34
# JP Morgan Chase NASDAQ                        63.2        61.6        61.2
#
#                                                274         275         276
# Date                                    2016-05-22  2016-05-29  2016-06-05
# Daimler DAX30                                57.83       60.68       61.39
# Deutsche Borse DAX30                         76.66       79.19        79.5
# Deutsche Bank DAX30                          15.14       16.29       16.06
# Deutsche Post DAX30                          25.87       26.68       26.25
# Deutsche Telekom DAX30                       15.91        15.9       15.78
# EON DAX30                                     8.32         8.9        8.56
# Fresenius DAX30                              64.99       68.03        67.5
# Heidelberg Cement DAX30                      74.88        76.5       76.07
# Henkel DAX30                                102.35      103.75       104.4
# Infineon DAX30                               12.49       13.41       13.18
# Lufthansa DAX30                               12.2       12.64       12.64
# Linde DAX30                                  127.6      133.85       134.0
# Lanxess DAX30                                42.42       43.01       42.87
# Merck DAX30                                  87.23       89.96        91.0
# Munchener Ruck DAX30                        159.75      169.45       167.1
# RWE DAX30                                    11.49        12.0       11.42
# SAP DAX30                                    69.44       72.77       72.62
# KS DAX30                                     21.65       22.46       21.59
# Siemens DAX30                                 94.0       98.69       96.98
# Thyssen Krupp DAX30                          18.53       19.66        19.6
# Volkswagen Group DAX30                      129.65      135.65       131.8
# Adidas DAX30                                112.87      115.76      114.61
# Beiersdorf DAX30                             79.04       80.28        81.7
# Continental DAX30                            185.2       191.4       193.2
# Commerzbank DAX30                             7.29       7.785       7.674
# Allianz DAX30                                137.4       146.0       146.1
# BASF DAX30                                   67.15        70.1        69.9
# Bayer DAX30                                  89.75       85.35        85.4
# BMW DAX30                                    71.85       74.85        75.6
# Coca Cola NASDAQ                             43.95       44.78       44.72
# McDonalds NASDAQ                            122.56      123.25      121.17
# 3m NASDAQ                                   165.01      168.89      168.04
# Nike NASDAQ                                  56.48       56.19       54.53
# Pfizer NASDAQ                                33.74       34.61       34.87
# The Travelers Companies NASDAQ              111.89      114.18      114.87
# United Technologies Corporation NASDAQ        99.1      100.76      100.79
# Visa NASDAQ                                  77.67       79.66       79.95
# Verizon Communications NASDAQ                49.66       50.62       50.77
# WalMart NASDAQ                               69.86       70.75       70.95
# Chevron NASDAQ                           99.790001  102.019997  100.529999
# Home Depot NASDAQ                       131.850006  133.940002  132.410004
# IBM NASDAQ                                  147.25  152.839996       153.5
# Intel NASDAQ                                 30.15       31.57       31.76
# Microsoft NASDAQ                         50.619999       52.32       52.48
# Procter Gamble NASDAQ                    80.019997       81.43   81.949997
# Cisco NASDAQ                                 27.97       28.92       29.08
# American Express NASDAQ                      63.92       65.52       66.41
# Boeing NASDAQ                               127.39      129.22      126.85
# Caterpillar NASDAQ                           69.87       71.96       73.62
# Walt Disney NASDAQ                           99.78      100.29       98.72
# General Electric NASDAQ                      29.56       30.12       30.05
# Goldman Sachs NASDAQ                        154.51      159.53      159.28
# JP Morgan Chase NASDAQ                       63.51       65.43       65.81
#
# [54 rows x 277 columns]

# %%
dates_orig = [datetime.strptime(d, "%Y-%m-%d").date() for d in df["Date"]]
names = list(df.columns[1:])
series_orig = df.iloc[:,1:].values.T

# %%
# Nos quedamos con los últimos puntos temporales para simplificar
dates_orig = dates_orig[-200:]
series_orig = series_orig[:,-200:]

# %%
print(np.shape(dates_orig))
series_orig.shape
# Out:
# (200,)
# (53, 200)

# %% [markdown]
# # **Preprocesado de datos**

# %%
PREPROCESAMIENTO = 3
                        # 0: no hay preprocesamiento (tabajamos con las series originales)
                        # 1: estandarización (media de cada serie 0,  std 1)
                        # 2: incrementos relativos
                        # 3: incrementos relativos logarítmicos ("rendimientos logarítmicos")

ncompanies = len(names)
series_preproc = series_orig.copy()
dates = dates_orig.copy()

if PREPROCESAMIENTO == 0:
    pass
elif PREPROCESAMIENTO == 1:
    for i in range(len(series_orig)):
        series_preproc[i] = (series_orig[i]-np.mean(series_orig[i]))/np.std(series_orig[i])
elif PREPROCESAMIENTO == 2:
    # división componente a componente
    series_preproc = np.divide(series_orig[:,1:], series_orig[:,0:-1]) - 1
    dates = dates[1:] # perdemos un punto temporal
else:
    # log de las divisiones componente a componente
    series_preproc = np.log(np.divide(series_orig[:,1:], series_orig[:,0:-1]))
    dates = dates[1:] # perdemos un punto temporal

ndates = len(dates)

print(series_preproc.shape)

EMPRESA_EJEMPLO = 1

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(dates_orig, series_orig[EMPRESA_EJEMPLO,:], 'k')
plt.title(names[EMPRESA_EJEMPLO]+" (sin preprocesar)")
plt.xlabel('Fecha')

plt.subplot(1,2,2)
plt.plot(dates, series_preproc[EMPRESA_EJEMPLO,:], 'k')
plt.title(names[EMPRESA_EJEMPLO]+" (preprocesamiento %d)"%PREPROCESAMIENTO)
plt.xlabel('Fecha')
plt.show()
# Out:
# (53, 199)

# %% [markdown]
# # **Clustering con k-means (usando las series temporales)**

# %%
from sklearn.cluster import KMeans

nclusters = 4 # parámetro que se puede cambiar

kmns = KMeans(n_clusters=nclusters, random_state = 1,
              n_init=100)

kmns.fit(series_preproc)
ids_clusters = kmns.labels_.tolist()


print('*** K-Means ***\n')
for i in range(nclusters):
    print("Número de compañías en el cluster %d: %d" % (i, ids_clusters.count(i)))

for i in range(nclusters):
    print("\nCompañías en el cluster %d:\n" % i)
    inds = (np.where(np.array(ids_clusters) == i))[0]
    for j in range(len(inds)):
        print("--- %s" % names[inds[j]])
    if PREPROCESAMIENTO == 0:
        plt.figure(figsize=(7,5))
        plt.plot(dates, (series_preproc[inds]).T, "k", alpha=0.1)
        plt.title("Cluster %d"%i)
        plt.show()
    else:
        plt.figure(figsize=(14,5))
        plt.subplot(1,2,1)
        plt.plot(dates, (series_preproc[inds]).T, "k", alpha=0.1)
        plt.title("Cluster %d"%i)
        plt.subplot(1,2,2)
        plt.plot(dates_orig, (series_orig[inds]).T, "k", alpha=0.1)
        plt.title("Cluster %d (series sin preprocesar)"%i)
        plt.show()
# Out:
# *** K-Means ***
#
# Número de compañías en el cluster 0: 24
# Número de compañías en el cluster 1: 1
# Número de compañías en el cluster 2: 27
# Número de compañías en el cluster 3: 1
#
# Compañías en el cluster 0:
#
# --- Coca Cola NASDAQ
# --- McDonalds NASDAQ
# --- 3m NASDAQ
# --- Nike NASDAQ
# --- Pfizer NASDAQ
# --- The Travelers Companies NASDAQ
# --- United Technologies Corporation NASDAQ
# --- Visa NASDAQ
# --- Verizon Communications NASDAQ
# --- WalMart NASDAQ
# --- Chevron NASDAQ
# --- Home Depot NASDAQ
# --- IBM NASDAQ
# --- Intel NASDAQ
# --- Microsoft NASDAQ
# --- Procter Gamble NASDAQ
# --- Cisco NASDAQ
# --- American Express NASDAQ
# --- Boeing NASDAQ
# --- Caterpillar NASDAQ
# --- Walt Disney NASDAQ
# --- General Electric NASDAQ
# --- Goldman Sachs NASDAQ
# --- JP Morgan Chase NASDAQ
# Compañías en el cluster 1:
#
# --- Commerzbank DAX30
# Compañías en el cluster 2:
#
# --- Daimler DAX30
# --- Deutsche Borse DAX30
# --- Deutsche Bank DAX30
# --- Deutsche Post DAX30
# --- Deutsche Telekom DAX30
# --- EON DAX30
# --- Heidelberg Cement DAX30
# --- Henkel DAX30
# --- Infineon DAX30
# --- Lufthansa DAX30
# --- Linde DAX30
# --- Lanxess DAX30
# --- Merck DAX30
# --- Munchener Ruck DAX30
# --- RWE DAX30
# --- SAP DAX30
# --- KS DAX30
# --- Siemens DAX30
# --- Thyssen Krupp DAX30
# --- Volkswagen Group DAX30
# --- Adidas DAX30
# --- Beiersdorf DAX30
# --- Continental DAX30
# --- Allianz DAX30
# --- BASF DAX30
# --- Bayer DAX30
# --- BMW DAX30
# Compañías en el cluster 3:
#
# --- Fresenius DAX30

# %% [markdown]
# # **Clustering jerárquico (usando las series temporales)**

# %%
# Opción 1: trabajamos con las series preprocesadas

from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage(series_preproc, "ward")

plt.figure(figsize=(15,20))
dendr = dendrogram(Z, orientation="left", labels=names,
                   leaf_font_size=14)

inds_leaves = dendr['leaves']

plt.tick_params(axis = 'x',
                which = 'both',
                bottom = 'off',
                top = 'off',
                labelbottom = 'off')

plt.tight_layout()
#plt.savefig('dendrograma_series.png', dpi = 300)

# %% [markdown]
# # **PCA usando las series temporales**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(series_preproc)
# We do not scale the information X since all the correlations
# share the same scale (from -1 to 1)

pc_x = 0
pc_y = 1
X = pca.transform(series_preproc)

#plt.figure(figsize=(17, 15))
fig, ax = plt.subplots(figsize=(17,15))
#ax.axis([0, 0.5, 0, 0.5])

colors = {0: 'red', 1: 'green', 2: 'blue', 3: 'magenta', 4: 'black'}

nclusters = len(np.unique(ids_clusters))

excluir = ["Fresenius DAX30", "Commerzbank DAX30"]

for c in range(nclusters):
    inds = (np.where(np.array(ids_clusters) == c))[0]
    inds = [ind for ind in inds if names[ind] not in excluir]
#    ax.plot(X[inds,pc_x], X[inds,pc_y], 'o', c = colors[c],
#            label = 'Cluster %d' % (c))
    ax.scatter(X[inds,pc_x], X[inds,pc_y],
               marker = 'o', c = colors[c],
               label = 'Cluster %d' % (c))

for i in range(len(X)):
    if names[i] not in excluir:
        plt.text(X[i,pc_x], X[i,pc_y], names[i], size=14,
                color=colors[ids_clusters[i]])

plt.legend(fontsize=16)
plt.xlabel('Principal component '+str(pc_x+1), fontsize=24)
plt.ylabel('Principal component '+str(pc_y+1), fontsize=24)
#plt.savefig('PCA_series.png', dpi = 300)
# Out:
# Text(0, 0.5, 'Principal component 2')

# %% [markdown]
# # **Repetimos los mismos análisis pero trabajando con la matriz de correlación (correlaciones de cada compañía con las otras)**

# %%
correlaciones = pd.DataFrame(series_preproc.T, columns=names).corr()
correlaciones
# Out:
#                                         Daimler DAX30  Deutsche Borse DAX30  \
# Daimler DAX30                                1.000000              0.531602
# Deutsche Borse DAX30                         0.531602              1.000000
# Deutsche Bank DAX30                          0.541811              0.422974
# Deutsche Post DAX30                          0.647376              0.560367
# Deutsche Telekom DAX30                       0.517890              0.542660
# EON DAX30                                    0.478723              0.442454
# Fresenius DAX30                              0.170266              0.209787
# Heidelberg Cement DAX30                      0.676334              0.445021
# Henkel DAX30                                 0.498885              0.485645
# Infineon DAX30                               0.628559              0.508948
# Lufthansa DAX30                              0.406062              0.359394
# Linde DAX30                                  0.587913              0.456181
# Lanxess DAX30                                0.559786              0.351657
# Merck DAX30                                  0.141372              0.214529
# Munchener Ruck DAX30                         0.545612              0.524474
# RWE DAX30                                    0.369445              0.275104
# SAP DAX30                                    0.469496              0.381045
# KS DAX30                                     0.397857              0.294897
# Siemens DAX30                                0.598001              0.525316
# Thyssen Krupp DAX30                          0.605405              0.403535
# Volkswagen Group DAX30                       0.555268              0.394794
# Adidas DAX30                                 0.484062              0.408485
# Beiersdorf DAX30                             0.572799              0.502295
# Continental DAX30                            0.794680              0.532469
# Commerzbank DAX30                            0.254661              0.140986
# Allianz DAX30                                0.652804              0.636709
# BASF DAX30                                   0.708549              0.520947
# Bayer DAX30                                  0.633488              0.504789
# BMW DAX30                                    0.808692              0.518741
# Coca Cola NASDAQ                             0.257073              0.182986
# McDonalds NASDAQ                             0.269896              0.255472
# 3m NASDAQ                                    0.500930              0.461693
# Nike NASDAQ                                  0.392149              0.352568
# Pfizer NASDAQ                                0.200051              0.208557
# The Travelers Companies NASDAQ               0.428742              0.434812
# United Technologies Corporation NASDAQ       0.510597              0.457400
# Visa NASDAQ                                  0.442937              0.354472
# Verizon Communications NASDAQ                0.284098              0.237438
# WalMart NASDAQ                               0.074883              0.109346
# Chevron NASDAQ                               0.379422              0.373591
# Home Depot NASDAQ                            0.377034              0.374541
# IBM NASDAQ                                   0.297600              0.280886
# Intel NASDAQ                                 0.344450              0.322571
# Microsoft NASDAQ                             0.345719              0.273895
# Procter Gamble NASDAQ                        0.222793              0.234492
# Cisco NASDAQ                                 0.446759              0.326718
# American Express NASDAQ                      0.398634              0.256513
# Boeing NASDAQ                                0.446917              0.371069
# Caterpillar NASDAQ                           0.436967              0.311037
# Walt Disney NASDAQ                           0.432856              0.413517
# General Electric NASDAQ                      0.466276              0.434214
# Goldman Sachs NASDAQ                         0.530791              0.379369
# JP Morgan Chase NASDAQ                       0.520655              0.397620
#
#                                         Deutsche Bank DAX30  \
# Daimler DAX30                                      0.541811
# Deutsche Borse DAX30                               0.422974
# Deutsche Bank DAX30                                1.000000
# Deutsche Post DAX30                                0.488200
# Deutsche Telekom DAX30                             0.421220
# EON DAX30                                          0.392255
# Fresenius DAX30                                    0.108859
# Heidelberg Cement DAX30                            0.464455
# Henkel DAX30                                       0.290681
# Infineon DAX30                                     0.463849
# Lufthansa DAX30                                    0.376874
# Linde DAX30                                        0.450134
# Lanxess DAX30                                      0.475109
# Merck DAX30                                        0.183101
# Munchener Ruck DAX30                               0.441506
# RWE DAX30                                          0.348737
# SAP DAX30                                          0.389524
# KS DAX30                                           0.350189
# Siemens DAX30                                      0.470598
# Thyssen Krupp DAX30                                0.545788
# Volkswagen Group DAX30                             0.405918
# Adidas DAX30                                       0.358087
# Beiersdorf DAX30                                   0.348895
# Continental DAX30                                  0.490545
# Commerzbank DAX30                                  0.327142
# Allianz DAX30                                      0.593315
# BASF DAX30                                         0.535177
# Bayer DAX30                                        0.417151
# BMW DAX30                                          0.591504
# Coca Cola NASDAQ                                   0.119319
# McDonalds NASDAQ                                   0.130628
# 3m NASDAQ                                          0.332881
# Nike NASDAQ                                        0.236073
# Pfizer NASDAQ                                      0.289707
# The Travelers Companies NASDAQ                     0.363339
# United Technologies Corporation NASDAQ             0.417633
# Visa NASDAQ                                        0.394581
# Verizon Communications NASDAQ                      0.203048
# WalMart NASDAQ                                     0.166923
# Chevron NASDAQ                                     0.341223
# Home Depot NASDAQ                                  0.305183
# IBM NASDAQ                                         0.302907
# Intel NASDAQ                                       0.250204
# Microsoft NASDAQ                                   0.230237
# Procter Gamble NASDAQ                              0.094592
# Cisco NASDAQ                                       0.382223
# American Express NASDAQ                            0.426459
# Boeing NASDAQ                                      0.317157
# Caterpillar NASDAQ                                 0.397389
# Walt Disney NASDAQ                                 0.372115
# General Electric NASDAQ                            0.342578
# Goldman Sachs NASDAQ                               0.539230
# JP Morgan Chase NASDAQ                             0.504709
#
#                                         Deutsche Post DAX30  \
# Daimler DAX30                                      0.647376
# Deutsche Borse DAX30                               0.560367
# Deutsche Bank DAX30                                0.488200
# Deutsche Post DAX30                                1.000000
# Deutsche Telekom DAX30                             0.652107
# EON DAX30                                          0.534514
# Fresenius DAX30                                    0.192893
# Heidelberg Cement DAX30                            0.555704
# Henkel DAX30                                       0.576606
# Infineon DAX30                                     0.555153
# Lufthansa DAX30                                    0.405993
# Linde DAX30                                        0.617668
# Lanxess DAX30                                      0.462458
# Merck DAX30                                        0.239753
# Munchener Ruck DAX30                               0.514899
# RWE DAX30                                          0.396462
# SAP DAX30                                          0.508779
# KS DAX30                                           0.307190
# Siemens DAX30                                      0.584518
# Thyssen Krupp DAX30                                0.498913
# Volkswagen Group DAX30                             0.404457
# Adidas DAX30                                       0.486008
# Beiersdorf DAX30                                   0.568152
# Continental DAX30                                  0.626305
# Commerzbank DAX30                                  0.183035
# Allianz DAX30                                      0.679744
# BASF DAX30                                         0.658634
# Bayer DAX30                                        0.687863
# BMW DAX30                                          0.603030
# Coca Cola NASDAQ                                   0.297650
# McDonalds NASDAQ                                   0.403544
# 3m NASDAQ                                          0.514567
# Nike NASDAQ                                        0.423004
# Pfizer NASDAQ                                      0.351237
# The Travelers Companies NASDAQ                     0.480625
# United Technologies Corporation NASDAQ             0.577782
# Visa NASDAQ                                        0.452208
# Verizon Communications NASDAQ                      0.315646
# WalMart NASDAQ                                     0.086706
# Chevron NASDAQ                                     0.453365
# Home Depot NASDAQ                                  0.462711
# IBM NASDAQ                                         0.297312
# Intel NASDAQ                                       0.396024
# Microsoft NASDAQ                                   0.300785
# Procter Gamble NASDAQ                              0.325698
# Cisco NASDAQ                                       0.379882
# American Express NASDAQ                            0.343824
# Boeing NASDAQ                                      0.519011
# Caterpillar NASDAQ                                 0.330083
# Walt Disney NASDAQ                                 0.460319
# General Electric NASDAQ                            0.456995
# Goldman Sachs NASDAQ                               0.409486
# JP Morgan Chase NASDAQ                             0.382284
#
#                                         Deutsche Telekom DAX30  EON DAX30  \
# Daimler DAX30                                         0.517890   0.478723
# Deutsche Borse DAX30                                  0.542660   0.442454
# Deutsche Bank DAX30                                   0.421220   0.392255
# Deutsche Post DAX30                                   0.652107   0.534514
# Deutsche Telekom DAX30                                1.000000   0.439110
# EON DAX30                                             0.439110   1.000000
# Fresenius DAX30                                       0.354238   0.134191
# Heidelberg Cement DAX30                               0.426675   0.489665
# Henkel DAX30                                          0.553650   0.414010
# Infineon DAX30                                        0.454513   0.420695
# Lufthansa DAX30                                       0.283462   0.320160
# Linde DAX30                                           0.543304   0.397341
# Lanxess DAX30                                         0.312044   0.322438
# Merck DAX30                                           0.328594   0.176610
# Munchener Ruck DAX30                                  0.486730   0.412947
# RWE DAX30                                             0.298379   0.684052
# SAP DAX30                                             0.443959   0.262307
# KS DAX30                                              0.309954   0.285799
# Siemens DAX30                                         0.497359   0.485929
# Thyssen Krupp DAX30                                   0.424958   0.383425
# Volkswagen Group DAX30                                0.348509   0.401893
# Adidas DAX30                                          0.376662   0.388483
# Beiersdorf DAX30                                      0.530827   0.499609
# Continental DAX30                                     0.491658   0.499174
# Commerzbank DAX30                                     0.175470   0.184537
# Allianz DAX30                                         0.554642   0.536647
# BASF DAX30                                            0.513932   0.494650
# Bayer DAX30                                           0.621691   0.452088
# BMW DAX30                                             0.517974   0.517984
# Coca Cola NASDAQ                                      0.254725   0.263579
# McDonalds NASDAQ                                      0.372003   0.403583
# 3m NASDAQ                                             0.392994   0.458796
# Nike NASDAQ                                           0.344979   0.416624
# Pfizer NASDAQ                                         0.269747   0.189912
# The Travelers Companies NASDAQ                        0.357505   0.392677
# United Technologies Corporation NASDAQ                0.337431   0.423714
# Visa NASDAQ                                           0.328433   0.387244
# Verizon Communications NASDAQ                         0.370697   0.333201
# WalMart NASDAQ                                        0.122770   0.105954
# Chevron NASDAQ                                        0.364245   0.481600
# Home Depot NASDAQ                                     0.314301   0.293546
# IBM NASDAQ                                            0.127758   0.252414
# Intel NASDAQ                                          0.294064   0.382939
# Microsoft NASDAQ                                      0.269897   0.357764
# Procter Gamble NASDAQ                                 0.236177   0.334620
# Cisco NASDAQ                                          0.249507   0.276667
# American Express NASDAQ                               0.226301   0.218637
# Boeing NASDAQ                                         0.357266   0.375776
# Caterpillar NASDAQ                                    0.221404   0.391107
# Walt Disney NASDAQ                                    0.377261   0.346124
# General Electric NASDAQ                               0.323166   0.444854
# Goldman Sachs NASDAQ                                  0.245960   0.441317
# JP Morgan Chase NASDAQ                                0.296646   0.495161
#
#                                         Fresenius DAX30  \
# Daimler DAX30                                  0.170266
# Deutsche Borse DAX30                           0.209787
# Deutsche Bank DAX30                            0.108859
# Deutsche Post DAX30                            0.192893
# Deutsche Telekom DAX30                         0.354238
# EON DAX30                                      0.134191
# Fresenius DAX30                                1.000000
# Heidelberg Cement DAX30                        0.146034
# Henkel DAX30                                   0.213608
# Infineon DAX30                                 0.140068
# Lufthansa DAX30                                0.196559
# Linde DAX30                                    0.190414
# Lanxess DAX30                                  0.114633
# Merck DAX30                                    0.111821
# Munchener Ruck DAX30                           0.276473
# RWE DAX30                                      0.074168
# SAP DAX30                                      0.160810
# KS DAX30                                       0.058192
# Siemens DAX30                                  0.159751
# Thyssen Krupp DAX30                            0.111325
# Volkswagen Group DAX30                         0.120296
# Adidas DAX30                                   0.145857
# Beiersdorf DAX30                               0.271292
# Continental DAX30                              0.147243
# Commerzbank DAX30                              0.032687
# Allianz DAX30                                  0.158010
# BASF DAX30                                     0.167981
# Bayer DAX30                                    0.235846
# BMW DAX30                                      0.145783
# Coca Cola NASDAQ                               0.068671
# McDonalds NASDAQ                               0.117541
# 3m NASDAQ                                      0.082051
# Nike NASDAQ                                    0.096872
# Pfizer NASDAQ                                  0.152144
# The Travelers Companies NASDAQ                 0.068974
# United Technologies Corporation NASDAQ         0.072481
# Visa NASDAQ                                    0.105383
# Verizon Communications NASDAQ                  0.142628
# WalMart NASDAQ                                 0.016570
# Chevron NASDAQ                                 0.062419
# Home Depot NASDAQ                              0.033571
# IBM NASDAQ                                     0.069273
# Intel NASDAQ                                   0.137864
# Microsoft NASDAQ                               0.032593
# Procter Gamble NASDAQ                          0.031217
# Cisco NASDAQ                                   0.079453
# American Express NASDAQ                        0.009265
# Boeing NASDAQ                                  0.102216
# Caterpillar NASDAQ                            -0.025952
# Walt Disney NASDAQ                             0.058885
# General Electric NASDAQ                        0.077515
# Goldman Sachs NASDAQ                           0.043579
# JP Morgan Chase NASDAQ                         0.065288
#
#                                         Heidelberg Cement DAX30  Henkel DAX30  \
# Daimler DAX30                                          0.676334      0.498885
# Deutsche Borse DAX30                                   0.445021      0.485645
# Deutsche Bank DAX30                                    0.464455      0.290681
# Deutsche Post DAX30                                    0.555704      0.576606
# Deutsche Telekom DAX30                                 0.426675      0.553650
# EON DAX30                                              0.489665      0.414010
# Fresenius DAX30                                        0.146034      0.213608
# Heidelberg Cement DAX30                                1.000000      0.484492
# Henkel DAX30                                           0.484492      1.000000
# Infineon DAX30                                         0.558789      0.472164
# Lufthansa DAX30                                        0.443930      0.252653
# Linde DAX30                                            0.515617      0.553491
# Lanxess DAX30                                          0.472577      0.371226
# Merck DAX30                                            0.117012      0.238524
# Munchener Ruck DAX30                                   0.407889      0.487397
# RWE DAX30                                              0.389464      0.288653
# SAP DAX30                                              0.364559      0.425543
# KS DAX30                                               0.365317      0.286925
# Siemens DAX30                                          0.524574      0.541839
# Thyssen Krupp DAX30                                    0.543016      0.406816
# Volkswagen Group DAX30                                 0.430033      0.407888
# Adidas DAX30                                           0.442225      0.485837
# Beiersdorf DAX30                                       0.503135      0.647706
# Continental DAX30                                      0.636585      0.526643
# Commerzbank DAX30                                      0.237648      0.132864
# Allianz DAX30                                          0.572112      0.538220
# BASF DAX30                                             0.587939      0.550736
# Bayer DAX30                                            0.524817      0.598940
# BMW DAX30                                              0.625517      0.492006
# Coca Cola NASDAQ                                       0.225061      0.331534
# McDonalds NASDAQ                                       0.288765      0.322152
# 3m NASDAQ                                              0.460602      0.457997
# Nike NASDAQ                                            0.319523      0.284385
# Pfizer NASDAQ                                          0.239293      0.277224
# The Travelers Companies NASDAQ                         0.411039      0.376564
# United Technologies Corporation NASDAQ                 0.524968      0.341063
# Visa NASDAQ                                            0.403002      0.404664
# Verizon Communications NASDAQ                          0.275688      0.286533
# WalMart NASDAQ                                         0.182178      0.192073
# Chevron NASDAQ                                         0.372958      0.302539
# Home Depot NASDAQ                                      0.386892      0.278151
# IBM NASDAQ                                             0.289733      0.263106
# Intel NASDAQ                                           0.300231      0.243138
# Microsoft NASDAQ                                       0.262960      0.290924
# Procter Gamble NASDAQ                                  0.195416      0.340932
# Cisco NASDAQ                                           0.345840      0.278462
# American Express NASDAQ                                0.321439      0.245499
# Boeing NASDAQ                                          0.450879      0.369399
# Caterpillar NASDAQ                                     0.420694      0.192097
# Walt Disney NASDAQ                                     0.359332      0.368410
# General Electric NASDAQ                                0.444839      0.434826
# Goldman Sachs NASDAQ                                   0.511844      0.297574
# JP Morgan Chase NASDAQ                                 0.459228      0.228443
#
#                                         Infineon DAX30  ...  Microsoft NASDAQ  \
# Daimler DAX30                                 0.628559  ...          0.345719
# Deutsche Borse DAX30                          0.508948  ...          0.273895
# Deutsche Bank DAX30                           0.463849  ...          0.230237
# Deutsche Post DAX30                           0.555153  ...          0.300785
# Deutsche Telekom DAX30                        0.454513  ...          0.269897
# EON DAX30                                     0.420695  ...          0.357764
# Fresenius DAX30                               0.140068  ...          0.032593
# Heidelberg Cement DAX30                       0.558789  ...          0.262960
# Henkel DAX30                                  0.472164  ...          0.290924
# Infineon DAX30                                1.000000  ...          0.339335
# Lufthansa DAX30                               0.380651  ...          0.285186
# Linde DAX30                                   0.427711  ...          0.212179
# Lanxess DAX30                                 0.496798  ...          0.174585
# Merck DAX30                                   0.169259  ...          0.098952
# Munchener Ruck DAX30                          0.505392  ...          0.215487
# RWE DAX30                                     0.341450  ...          0.127468
# SAP DAX30                                     0.490105  ...          0.304328
# KS DAX30                                      0.279782  ...          0.059597
# Siemens DAX30                                 0.545467  ...          0.284225
# Thyssen Krupp DAX30                           0.533965  ...          0.193779
# Volkswagen Group DAX30                        0.409003  ...          0.153444
# Adidas DAX30                                  0.488996  ...          0.406854
# Beiersdorf DAX30                              0.437926  ...          0.378247
# Continental DAX30                             0.673217  ...          0.353699
# Commerzbank DAX30                             0.240775  ...          0.206502
# Allianz DAX30                                 0.585303  ...          0.314920
# BASF DAX30                                    0.581943  ...          0.300887
# Bayer DAX30                                   0.457177  ...          0.285927
# BMW DAX30                                     0.652799  ...          0.270406
# Coca Cola NASDAQ                              0.194371  ...          0.401794
# McDonalds NASDAQ                              0.286888  ...          0.437009
# 3m NASDAQ                                     0.482144  ...          0.457314
# Nike NASDAQ                                   0.328492  ...          0.458450
# Pfizer NASDAQ                                 0.198137  ...          0.282442
# The Travelers Companies NASDAQ                0.365848  ...          0.476887
# United Technologies Corporation NASDAQ        0.512689  ...          0.394188
# Visa NASDAQ                                   0.424422  ...          0.464541
# Verizon Communications NASDAQ                 0.207186  ...          0.427796
# WalMart NASDAQ                                0.045942  ...          0.171074
# Chevron NASDAQ                                0.440602  ...          0.462544
# Home Depot NASDAQ                             0.404049  ...          0.388416
# IBM NASDAQ                                    0.297801  ...          0.257732
# Intel NASDAQ                                  0.360241  ...          0.554285
# Microsoft NASDAQ                              0.339335  ...          1.000000
# Procter Gamble NASDAQ                         0.179320  ...          0.401465
# Cisco NASDAQ                                  0.316603  ...          0.487479
# American Express NASDAQ                       0.224621  ...          0.269585
# Boeing NASDAQ                                 0.342536  ...          0.205403
# Caterpillar NASDAQ                            0.427272  ...          0.359809
# Walt Disney NASDAQ                            0.371226  ...          0.445177
# General Electric NASDAQ                       0.419222  ...          0.451114
# Goldman Sachs NASDAQ                          0.450324  ...          0.346847
# JP Morgan Chase NASDAQ                        0.383732  ...          0.369094
#
#                                         Procter Gamble NASDAQ  Cisco NASDAQ  \
# Daimler DAX30                                        0.222793      0.446759
# Deutsche Borse DAX30                                 0.234492      0.326718
# Deutsche Bank DAX30                                  0.094592      0.382223
# Deutsche Post DAX30                                  0.325698      0.379882
# Deutsche Telekom DAX30                               0.236177      0.249507
# EON DAX30                                            0.334620      0.276667
# Fresenius DAX30                                      0.031217      0.079453
# Heidelberg Cement DAX30                              0.195416      0.345840
# Henkel DAX30                                         0.340932      0.278462
# Infineon DAX30                                       0.179320      0.316603
# Lufthansa DAX30                                      0.145440      0.139691
# Linde DAX30                                          0.221184      0.283625
# Lanxess DAX30                                        0.107885      0.256335
# Merck DAX30                                          0.109000      0.102500
# Munchener Ruck DAX30                                 0.279835      0.265079
# RWE DAX30                                            0.245502      0.143446
# SAP DAX30                                            0.272753      0.220067
# KS DAX30                                            -0.002161      0.117684
# Siemens DAX30                                        0.252663      0.338392
# Thyssen Krupp DAX30                                  0.179124      0.347369
# Volkswagen Group DAX30                               0.191184      0.251469
# Adidas DAX30                                         0.268393      0.368664
# Beiersdorf DAX30                                     0.367684      0.324009
# Continental DAX30                                    0.296651      0.362635
# Commerzbank DAX30                                   -0.148057      0.110975
# Allianz DAX30                                        0.307342      0.391724
# BASF DAX30                                           0.177653      0.370171
# Bayer DAX30                                          0.261151      0.304180
# BMW DAX30                                            0.195314      0.324093
# Coca Cola NASDAQ                                     0.546893      0.388337
# McDonalds NASDAQ                                     0.440372      0.400405
# 3m NASDAQ                                            0.499273      0.522459
# Nike NASDAQ                                          0.388207      0.347485
# Pfizer NASDAQ                                        0.355883      0.292114
# The Travelers Companies NASDAQ                       0.550640      0.501728
# United Technologies Corporation NASDAQ               0.428265      0.499044
# Visa NASDAQ                                          0.367539      0.400542
# Verizon Communications NASDAQ                        0.488252      0.303820
# WalMart NASDAQ                                       0.306503      0.126047
# Chevron NASDAQ                                       0.472109      0.488630
# Home Depot NASDAQ                                    0.430321      0.395952
# IBM NASDAQ                                           0.192295      0.357455
# Intel NASDAQ                                         0.358554      0.452309
# Microsoft NASDAQ                                     0.401465      0.487479
# Procter Gamble NASDAQ                                1.000000      0.359299
# Cisco NASDAQ                                         0.359299      1.000000
# American Express NASDAQ                              0.217632      0.300837
# Boeing NASDAQ                                        0.257691      0.312877
# Caterpillar NASDAQ                                   0.260715      0.378937
# Walt Disney NASDAQ                                   0.475578      0.418682
# General Electric NASDAQ                              0.451184      0.482684
# Goldman Sachs NASDAQ                                 0.315570      0.465203
# JP Morgan Chase NASDAQ                               0.341198      0.461194
#
#                                         American Express NASDAQ  \
# Daimler DAX30                                          0.398634
# Deutsche Borse DAX30                                   0.256513
# Deutsche Bank DAX30                                    0.426459
# Deutsche Post DAX30                                    0.343824
# Deutsche Telekom DAX30                                 0.226301
# EON DAX30                                              0.218637
# Fresenius DAX30                                        0.009265
# Heidelberg Cement DAX30                                0.321439
# Henkel DAX30                                           0.245499
# Infineon DAX30                                         0.224621
# Lufthansa DAX30                                        0.226407
# Linde DAX30                                            0.272375
# Lanxess DAX30                                          0.279183
# Merck DAX30                                            0.087381
# Munchener Ruck DAX30                                   0.282490
# RWE DAX30                                              0.209137
# SAP DAX30                                              0.256452
# KS DAX30                                               0.221240
# Siemens DAX30                                          0.332480
# Thyssen Krupp DAX30                                    0.404374
# Volkswagen Group DAX30                                 0.273299
# Adidas DAX30                                           0.212488
# Beiersdorf DAX30                                       0.186963
# Continental DAX30                                      0.350297
# Commerzbank DAX30                                      0.110582
# Allianz DAX30                                          0.339889
# BASF DAX30                                             0.287768
# Bayer DAX30                                            0.314787
# BMW DAX30                                              0.373363
# Coca Cola NASDAQ                                       0.311319
# McDonalds NASDAQ                                       0.100922
# 3m NASDAQ                                              0.437932
# Nike NASDAQ                                            0.259114
# Pfizer NASDAQ                                          0.253897
# The Travelers Companies NASDAQ                         0.355603
# United Technologies Corporation NASDAQ                 0.431301
# Visa NASDAQ                                            0.444640
# Verizon Communications NASDAQ                          0.275027
# WalMart NASDAQ                                         0.309202
# Chevron NASDAQ                                         0.319834
# Home Depot NASDAQ                                      0.381697
# IBM NASDAQ                                             0.350249
# Intel NASDAQ                                           0.277803
# Microsoft NASDAQ                                       0.269585
# Procter Gamble NASDAQ                                  0.217632
# Cisco NASDAQ                                           0.300837
# American Express NASDAQ                                1.000000
# Boeing NASDAQ                                          0.394738
# Caterpillar NASDAQ                                     0.408605
# Walt Disney NASDAQ                                     0.364644
# General Electric NASDAQ                                0.346393
# Goldman Sachs NASDAQ                                   0.523331
# JP Morgan Chase NASDAQ                                 0.530457
#
#                                         Boeing NASDAQ  Caterpillar NASDAQ  \
# Daimler DAX30                                0.446917            0.436967
# Deutsche Borse DAX30                         0.371069            0.311037
# Deutsche Bank DAX30                          0.317157            0.397389
# Deutsche Post DAX30                          0.519011            0.330083
# Deutsche Telekom DAX30                       0.357266            0.221404
# EON DAX30                                    0.375776            0.391107
# Fresenius DAX30                              0.102216           -0.025952
# Heidelberg Cement DAX30                      0.450879            0.420694
# Henkel DAX30                                 0.369399            0.192097
# Infineon DAX30                               0.342536            0.427272
# Lufthansa DAX30                              0.355378            0.276509
# Linde DAX30                                  0.375463            0.328359
# Lanxess DAX30                                0.306850            0.423602
# Merck DAX30                                  0.204422            0.000225
# Munchener Ruck DAX30                         0.369118            0.268313
# RWE DAX30                                    0.245129            0.335524
# SAP DAX30                                    0.282031            0.258382
# KS DAX30                                     0.213368            0.214290
# Siemens DAX30                                0.353542            0.427052
# Thyssen Krupp DAX30                          0.352306            0.497559
# Volkswagen Group DAX30                       0.270565            0.333502
# Adidas DAX30                                 0.388171            0.310478
# Beiersdorf DAX30                             0.323598            0.191392
# Continental DAX30                            0.451306            0.408414
# Commerzbank DAX30                            0.160407            0.246734
# Allianz DAX30                                0.457361            0.366927
# BASF DAX30                                   0.501454            0.501576
# Bayer DAX30                                  0.402750            0.301055
# BMW DAX30                                    0.440095            0.442969
# Coca Cola NASDAQ                             0.351330            0.290782
# McDonalds NASDAQ                             0.317757            0.201554
# 3m NASDAQ                                    0.495752            0.502320
# Nike NASDAQ                                  0.410503            0.266842
# Pfizer NASDAQ                                0.242564            0.158006
# The Travelers Companies NASDAQ               0.392102            0.423483
# United Technologies Corporation NASDAQ       0.462775            0.561513
# Visa NASDAQ                                  0.412968            0.318894
# Verizon Communications NASDAQ                0.323387            0.354528
# WalMart NASDAQ                               0.171617            0.257325
# Chevron NASDAQ                               0.411555            0.442673
# Home Depot NASDAQ                            0.370001            0.308542
# IBM NASDAQ                                   0.377799            0.412001
# Intel NASDAQ                                 0.319850            0.402320
# Microsoft NASDAQ                             0.205403            0.359809
# Procter Gamble NASDAQ                        0.257691            0.260715
# Cisco NASDAQ                                 0.312877            0.378937
# American Express NASDAQ                      0.394738            0.408605
# Boeing NASDAQ                                1.000000            0.315364
# Caterpillar NASDAQ                           0.315364            1.000000
# Walt Disney NASDAQ                           0.427506            0.401644
# General Electric NASDAQ                      0.472160            0.541810
# Goldman Sachs NASDAQ                         0.448839            0.566421
# JP Morgan Chase NASDAQ                       0.364595            0.530386
#
#                                         Walt Disney NASDAQ  \
# Daimler DAX30                                     0.432856
# Deutsche Borse DAX30                              0.413517
# Deutsche Bank DAX30                               0.372115
# Deutsche Post DAX30                               0.460319
# Deutsche Telekom DAX30                            0.377261
# EON DAX30                                         0.346124
# Fresenius DAX30                                   0.058885
# Heidelberg Cement DAX30                           0.359332
# Henkel DAX30                                      0.368410
# Infineon DAX30                                    0.371226
# Lufthansa DAX30                                   0.233538
# Linde DAX30                                       0.390694
# Lanxess DAX30                                     0.349740
# Merck DAX30                                       0.150412
# Munchener Ruck DAX30                              0.325147
# RWE DAX30                                         0.232418
# SAP DAX30                                         0.301096
# KS DAX30                                          0.258564
# Siemens DAX30                                     0.347653
# Thyssen Krupp DAX30                               0.284299
# Volkswagen Group DAX30                            0.306027
# Adidas DAX30                                      0.383784
# Beiersdorf DAX30                                  0.348967
# Continental DAX30                                 0.414036
# Commerzbank DAX30                                 0.097628
# Allianz DAX30                                     0.420994
# BASF DAX30                                        0.382447
# Bayer DAX30                                       0.398259
# BMW DAX30                                         0.451829
# Coca Cola NASDAQ                                  0.334950
# McDonalds NASDAQ                                  0.362032
# 3m NASDAQ                                         0.556229
# Nike NASDAQ                                       0.538978
# Pfizer NASDAQ                                     0.420231
# The Travelers Companies NASDAQ                    0.506379
# United Technologies Corporation NASDAQ            0.536022
# Visa NASDAQ                                       0.510631
# Verizon Communications NASDAQ                     0.505125
# WalMart NASDAQ                                    0.255227
# Chevron NASDAQ                                    0.493814
# Home Depot NASDAQ                                 0.568249
# IBM NASDAQ                                        0.310421
# Intel NASDAQ                                      0.455974
# Microsoft NASDAQ                                  0.445177
# Procter Gamble NASDAQ                             0.475578
# Cisco NASDAQ                                      0.418682
# American Express NASDAQ                           0.364644
# Boeing NASDAQ                                     0.427506
# Caterpillar NASDAQ                                0.401644
# Walt Disney NASDAQ                                1.000000
# General Electric NASDAQ                           0.468444
# Goldman Sachs NASDAQ                              0.556374
# JP Morgan Chase NASDAQ                            0.487122
#
#                                         General Electric NASDAQ  \
# Daimler DAX30                                          0.466276
# Deutsche Borse DAX30                                   0.434214
# Deutsche Bank DAX30                                    0.342578
# Deutsche Post DAX30                                    0.456995
# Deutsche Telekom DAX30                                 0.323166
# EON DAX30                                              0.444854
# Fresenius DAX30                                        0.077515
# Heidelberg Cement DAX30                                0.444839
# Henkel DAX30                                           0.434826
# Infineon DAX30                                         0.419222
# Lufthansa DAX30                                        0.262062
# Linde DAX30                                            0.395808
# Lanxess DAX30                                          0.340249
# Merck DAX30                                            0.129218
# Munchener Ruck DAX30                                   0.369254
# RWE DAX30                                              0.263074
# SAP DAX30                                              0.338747
# KS DAX30                                               0.212493
# Siemens DAX30                                          0.442880
# Thyssen Krupp DAX30                                    0.379983
# Volkswagen Group DAX30                                 0.289985
# Adidas DAX30                                           0.482529
# Beiersdorf DAX30                                       0.442556
# Continental DAX30                                      0.494222
# Commerzbank DAX30                                      0.154642
# Allianz DAX30                                          0.514227
# BASF DAX30                                             0.520720
# Bayer DAX30                                            0.430476
# BMW DAX30                                              0.446852
# Coca Cola NASDAQ                                       0.447987
# McDonalds NASDAQ                                       0.476889
# 3m NASDAQ                                              0.697791
# Nike NASDAQ                                            0.389153
# Pfizer NASDAQ                                          0.363790
# The Travelers Companies NASDAQ                         0.581911
# United Technologies Corporation NASDAQ                 0.560330
# Visa NASDAQ                                            0.483332
# Verizon Communications NASDAQ                          0.404956
# WalMart NASDAQ                                         0.137470
# Chevron NASDAQ                                         0.576098
# Home Depot NASDAQ                                      0.431116
# IBM NASDAQ                                             0.369142
# Intel NASDAQ                                           0.454283
# Microsoft NASDAQ                                       0.451114
# Procter Gamble NASDAQ                                  0.451184
# Cisco NASDAQ                                           0.482684
# American Express NASDAQ                                0.346393
# Boeing NASDAQ                                          0.472160
# Caterpillar NASDAQ                                     0.541810
# Walt Disney NASDAQ                                     0.468444
# General Electric NASDAQ                                1.000000
# Goldman Sachs NASDAQ                                   0.557725
# JP Morgan Chase NASDAQ                                 0.575454
#
#                                         Goldman Sachs NASDAQ  \
# Daimler DAX30                                       0.530791
# Deutsche Borse DAX30                                0.379369
# Deutsche Bank DAX30                                 0.539230
# Deutsche Post DAX30                                 0.409486
# Deutsche Telekom DAX30                              0.245960
# EON DAX30                                           0.441317
# Fresenius DAX30                                     0.043579
# Heidelberg Cement DAX30                             0.511844
# Henkel DAX30                                        0.297574
# Infineon DAX30                                      0.450324
# Lufthansa DAX30                                     0.275134
# Linde DAX30                                         0.407853
# Lanxess DAX30                                       0.428017
# Merck DAX30                                         0.107843
# Munchener Ruck DAX30                                0.322999
# RWE DAX30                                           0.400297
# SAP DAX30                                           0.324025
# KS DAX30                                            0.250325
# Siemens DAX30                                       0.454482
# Thyssen Krupp DAX30                                 0.494462
# Volkswagen Group DAX30                              0.337902
# Adidas DAX30                                        0.333391
# Beiersdorf DAX30                                    0.270328
# Continental DAX30                                   0.487634
# Commerzbank DAX30                                   0.221616
# Allianz DAX30                                       0.481223
# BASF DAX30                                          0.469834
# Bayer DAX30                                         0.381200
# BMW DAX30                                           0.500386
# Coca Cola NASDAQ                                    0.257891
# McDonalds NASDAQ                                    0.242967
# 3m NASDAQ                                           0.536085
# Nike NASDAQ                                         0.390528
# Pfizer NASDAQ                                       0.296618
# The Travelers Companies NASDAQ                      0.465671
# United Technologies Corporation NASDAQ              0.578396
# Visa NASDAQ                                         0.517114
# Verizon Communications NASDAQ                       0.313929
# WalMart NASDAQ                                      0.250872
# Chevron NASDAQ                                      0.490425
# Home Depot NASDAQ                                   0.491842
# IBM NASDAQ                                          0.417210
# Intel NASDAQ                                        0.369878
# Microsoft NASDAQ                                    0.346847
# Procter Gamble NASDAQ                               0.315570
# Cisco NASDAQ                                        0.465203
# American Express NASDAQ                             0.523331
# Boeing NASDAQ                                       0.448839
# Caterpillar NASDAQ                                  0.566421
# Walt Disney NASDAQ                                  0.556374
# General Electric NASDAQ                             0.557725
# Goldman Sachs NASDAQ                                1.000000
# JP Morgan Chase NASDAQ                              0.809937
#
#                                         JP Morgan Chase NASDAQ
# Daimler DAX30                                         0.520655
# Deutsche Borse DAX30                                  0.397620
# Deutsche Bank DAX30                                   0.504709
# Deutsche Post DAX30                                   0.382284
# Deutsche Telekom DAX30                                0.296646
# EON DAX30                                             0.495161
# Fresenius DAX30                                       0.065288
# Heidelberg Cement DAX30                               0.459228
# Henkel DAX30                                          0.228443
# Infineon DAX30                                        0.383732
# Lufthansa DAX30                                       0.271031
# Linde DAX30                                           0.381857
# Lanxess DAX30                                         0.370006
# Merck DAX30                                           0.143355
# Munchener Ruck DAX30                                  0.315776
# RWE DAX30                                             0.407431
# SAP DAX30                                             0.313599
# KS DAX30                                              0.217870
# Siemens DAX30                                         0.437939
# Thyssen Krupp DAX30                                   0.484229
# Volkswagen Group DAX30                                0.322033
# Adidas DAX30                                          0.347885
# Beiersdorf DAX30                                      0.278792
# Continental DAX30                                     0.457150
# Commerzbank DAX30                                     0.220967
# Allianz DAX30                                         0.480517
# BASF DAX30                                            0.396026
# Bayer DAX30                                           0.370953
# BMW DAX30                                             0.516866
# Coca Cola NASDAQ                                      0.267222
# McDonalds NASDAQ                                      0.265299
# 3m NASDAQ                                             0.505773
# Nike NASDAQ                                           0.374478
# Pfizer NASDAQ                                         0.356879
# The Travelers Companies NASDAQ                        0.500529
# United Technologies Corporation NASDAQ                0.489961
# Visa NASDAQ                                           0.460171
# Verizon Communications NASDAQ                         0.346294
# WalMart NASDAQ                                        0.255334
# Chevron NASDAQ                                        0.530297
# Home Depot NASDAQ                                     0.497589
# IBM NASDAQ                                            0.316326
# Intel NASDAQ                                          0.364183
# Microsoft NASDAQ                                      0.369094
# Procter Gamble NASDAQ                                 0.341198
# Cisco NASDAQ                                          0.461194
# American Express NASDAQ                               0.530457
# Boeing NASDAQ                                         0.364595
# Caterpillar NASDAQ                                    0.530386
# Walt Disney NASDAQ                                    0.487122
# General Electric NASDAQ                               0.575454
# Goldman Sachs NASDAQ                                  0.809937
# JP Morgan Chase NASDAQ                                1.000000
#
# [53 rows x 53 columns]

# %%
sns.clustermap(correlaciones, figsize=(25,25), cmap="bwr", vmin=-1, vmax=1);

# %% [markdown]
# # **Clustering con k-means (usando las correlaciones)**

# %%
kmns = KMeans(n_clusters=nclusters, random_state = 1, n_init=100)

kmns.fit(correlaciones)
ids_clusters = kmns.labels_.tolist()


print('*** K-Means ***\n')
for i in range(nclusters):
    print("Número de compañías en el cluster %d: %d" % (i, ids_clusters.count(i)))

for i in range(nclusters):
    print("\nCompañías en el cluster %d:\n" % i)
    inds = (np.where(np.array(ids_clusters) == i))[0]
    for j in range(len(inds)):
        print("--- %s" % names[inds[j]])
    plt.figure(figsize=(17,5))
    plt.plot(correlaciones.iloc[:,inds], "k", alpha=0.2)
    plt.xticks(rotation=90)
    plt.title("Cluster %d"%i)
    plt.show()
# Out:
# *** K-Means ***
#
# Número de compañías en el cluster 0: 22
# Número de compañías en el cluster 1: 8
# Número de compañías en el cluster 2: 9
# Número de compañías en el cluster 3: 14
#
# Compañías en el cluster 0:
#
# --- Daimler DAX30
# --- Deutsche Borse DAX30
# --- Deutsche Bank DAX30
# --- Deutsche Post DAX30
# --- Deutsche Telekom DAX30
# --- EON DAX30
# --- Heidelberg Cement DAX30
# --- Henkel DAX30
# --- Infineon DAX30
# --- Linde DAX30
# --- Lanxess DAX30
# --- Munchener Ruck DAX30
# --- SAP DAX30
# --- Siemens DAX30
# --- Thyssen Krupp DAX30
# --- Adidas DAX30
# --- Beiersdorf DAX30
# --- Continental DAX30
# --- Allianz DAX30
# --- BASF DAX30
# --- Bayer DAX30
# --- BMW DAX30
# Compañías en el cluster 1:
#
# --- Coca Cola NASDAQ
# --- McDonalds NASDAQ
# --- Nike NASDAQ
# --- Pfizer NASDAQ
# --- Verizon Communications NASDAQ
# --- Intel NASDAQ
# --- Microsoft NASDAQ
# --- Procter Gamble NASDAQ
# Compañías en el cluster 2:
#
# --- Fresenius DAX30
# --- Lufthansa DAX30
# --- Merck DAX30
# --- RWE DAX30
# --- KS DAX30
# --- Volkswagen Group DAX30
# --- Commerzbank DAX30
# --- WalMart NASDAQ
# --- IBM NASDAQ
# Compañías en el cluster 3:
#
# --- 3m NASDAQ
# --- The Travelers Companies NASDAQ
# --- United Technologies Corporation NASDAQ
# --- Visa NASDAQ
# --- Chevron NASDAQ
# --- Home Depot NASDAQ
# --- Cisco NASDAQ
# --- American Express NASDAQ
# --- Boeing NASDAQ
# --- Caterpillar NASDAQ
# --- Walt Disney NASDAQ
# --- General Electric NASDAQ
# --- Goldman Sachs NASDAQ
# --- JP Morgan Chase NASDAQ

# %% [markdown]
# # **Clustering jerárquico (usando las correlaciones)**

# %%
Z = linkage(correlaciones, "ward")

plt.figure(figsize=(15,20))
dendr = dendrogram(Z, orientation="left", labels=names,
                   leaf_font_size=14)

inds_leaves = dendr['leaves']

plt.tick_params(axis = 'x',
                which = 'both',
                bottom = 'off',
                top = 'off',
                labelbottom = 'off')

plt.tight_layout();
#plt.savefig('dendrograma2.png', dpi = 300)

# %% [markdown]
# # **PCA usando los vectores de correlaciones**

# %%
pc_x = 0
pc_y = 1
pca = PCA(n_components=2)
pca.fit(correlaciones)
# We do not scale the information X since all the correlations
# share the same scale (from -1 to 1)

X = pca.transform(correlaciones)

fig, ax = plt.subplots(figsize=(17, 15))
colors = {0: 'red', 1: 'green', 2: 'blue', 3: 'magenta', 4: 'black'}

for i in range((np.shape(X))[0]):
    ax.text(X[i,pc_x], X[i,pc_y], names[i], size=14,
            color=colors[ids_clusters[i]])

nclusters = len(np.unique(ids_clusters))

for c in range(nclusters):
    inds = (np.where(np.array(ids_clusters) == c))[0]
    plt.scatter(X[inds,pc_x], X[inds,pc_y],
                marker = 'o', c = colors[c],
                label = 'Cluster %d' % (c))

plt.legend(fontsize=16)
plt.xlabel('Principal component '+str(pc_x+1), fontsize=24)
plt.ylabel('Principal component '+str(pc_y+1), fontsize=24);
#plt.savefig('PCA_correlaciones.png', dpi = 300)
