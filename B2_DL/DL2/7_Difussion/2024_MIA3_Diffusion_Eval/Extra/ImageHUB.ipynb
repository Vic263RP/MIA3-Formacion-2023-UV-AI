# %% [markdown]
# https://github.com/TIGER-AI-Lab/ImagenHub

# %%
# !git clone https://git@github.com/TIGER-AI-Lab/ImagenHub
# Out:
# Cloning into 'ImagenHub'...
# remote: Enumerating objects: 2671, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 2671 (delta 56), reused 51 (delta 21), pack-reused 2548
# Receiving objects: 100% (2671/2671), 96.12 MiB | 27.70 MiB/s, done.
# Resolving deltas: 100% (924/924), done.

# %%
# !cd ImagenHub
# Out:
# ERROR: unknown command "env"
# ERROR: unknown command "activate"
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !pip install diffusers==0.11.1
# !pip install transformers scipy ftfy accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import imagen_hub

model = imagen_hub.load("SDXL")
image = model.infer_one_image(prompt="people reading pictures in a museum, watercolor", seed=1)
image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-5f56b96d9fd7> in <cell line: 1>()
# ----> 1 import imagen_hub
#       2
#       3 model = imagen_hub.load("SDXL")
#       4 image = model.infer_one_image(prompt="people reading pictures in a museum, watercolor", seed=1)
#       5 image
#
# /usr/local/lib/python3.10/dist-packages/imagen_hub/__init__.py in <module>
#       1 from ._version import __version__
# ----> 2 from .infermodels import load, get_model, load_model
#
# /usr/local/lib/python3.10/dist-packages/imagen_hub/infermodels/__init__.py in <module>
#       4 from .sd import SD, OpenJourney, LCM, PlayGroundV2
#       5 from .sdxl import SDXL, SDXLTurbo, SSD
# ----> 6 from .deepfloydif import DeepFloydIF
#       7 from .dalle import DALLE2, DALLE3, StableUnCLIP
#       8 from .unidiffuser import UniDiffuser
#
# ...
